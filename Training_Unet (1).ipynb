# %% [markdown]
# # Baseline U-Net (Improved)
#
# So sánh với MiT+pscSE. Các cải tiến so với baseline cũ:
#
# | | Baseline cũ | Baseline mới (notebook này) |
# |---|---|---|
# | Encoder | ResNet34 | **ResNet50** (mạnh hơn) |
# | Loss | Dice + CE | **Dice + Focal Loss** (xử lý class imbalance) |
# | Class weights | Không có | **Tự động tính từ dataset** |
# | Augmentation | Cơ bản | **Thêm CoarseDropout, ElasticTransform** |
# | LR Warmup | Không | **Cosine Annealing với Warmup** |
# | num_workers | 0 | **2** (tải data nhanh hơn) |

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q -U albumentations
# !pip install -q -U timm
# !pip install -q -U opencv-python-headless
# !pip install -q segmentation-models-pytorch
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 6.2 MB/s eta 0:00:00

# %%
import sys, os

PROJECT_ROOT = "/content/drive/MyDrive/DFUTissueSegNet"
CODES_DIR    = PROJECT_ROOT + "/Codes"

sys.path.insert(0, PROJECT_ROOT)
sys.path.insert(0, CODES_DIR)

print("PROJECT_ROOT:", PROJECT_ROOT)
print("CODES_DIR   :", CODES_DIR)
# Out:
# PROJECT_ROOT: /content/drive/MyDrive/DFUTissueSegNet
# CODES_DIR   : /content/drive/MyDrive/DFUTissueSegNet/Codes

# %%
import cv2
import json
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy
from datetime import datetime
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader

import albumentations as albu
# !pip install -q -U pretrainedmodels
# !pip install -q -U efficientnet_pytorch
import segmentation_models_pytorch as smp
from segmentation_models_pytorch.utils import losses, base

warnings.filterwarnings('ignore')
# %matplotlib inline

print('torch     :', torch.__version__)
print('smp       :', smp.__version__)
print('albument. :', albu.__version__)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Building wheel for efficientnet_pytorch (setup.py) ... done
# torch     : 2.10.0+cu128
# smp       : 0.3.3
# albument. : 2.0.8

# %% [markdown]
# ## Parameters

# %%
# ================================================================
#  MODEL
# ================================================================
BASE_MODEL       = 'UNet_resnet50_improved'
ENCODER          = 'resnet50'      # mạnh hơn resnet34, vẫn nhẹ hơn MiT-B3
ENCODER_WEIGHTS  = 'imagenet'

# ================================================================
#  DATA
# ================================================================
BATCH_SIZE     = 8        # giảm vì resnet50 nặng hơn resnet34
n_classes      = 4
RESIZE         = (256, 256)
TO_CATEGORICAL = True

# ================================================================
#  TRAINING
# ================================================================
ACTIVATION   = 'softmax'
DEVICE       = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

LR           = 1e-4
WEIGHT_DECAY = 1e-4      # tăng nhẹ để regularize tốt hơn
EPOCHS       = 300

SAVE_BEST_MODEL  = True
SAVE_LAST_MODEL  = False
SAVE_WEIGHTS_ONLY = True
PERIOD           = 10
RAW_PREDICTION   = False

EARLY_STOP = True
PATIENCE   = 40

# ================================================================
#  FOCAL LOSS
# ================================================================
FOCAL_GAMMA = 2.0   # gamma càng lớn → tập trung class khó (label 1) càng nhiều

print(f'Device  : {DEVICE}')
print(f'Encoder : {ENCODER}')
# Out:
# Device  : cuda
# Encoder : resnet50

# %% [markdown]
# ## Helper functions

# %%
def read_names(txt_file, ext='.png'):
    with open(txt_file, 'r') as f:
        names = f.readlines()
    names = [n.strip('\n') + ext for n in names]
    return names


def fix_case_filenames(img_dir, names):
    real_files = {f.lower(): f for f in os.listdir(img_dir)}
    fixed = []
    for n in names:
        if n.lower() in real_files:
            fixed.append(real_files[n.lower()])
        else:
            raise FileNotFoundError(f'❌ File {n} not found in {img_dir}')
    return fixed


def save_checkpoint(model_path, epoch, model_state_dict, optimizer_state_dict):
    state = {
        'epoch'     : epoch + 1,
        'state_dict': deepcopy(model_state_dict),
        'optimizer' : deepcopy(optimizer_state_dict),
    }
    torch.save(state, model_path)


# ================================================================
#  Tính class weight tự động từ toàn bộ training masks
#  → giải quyết class imbalance (label 1 bị bỏ qua)
# ================================================================
def compute_class_weights(mask_dir, names, n_classes=4, device='cpu'):
    print('⏳ Đang tính class weights từ training masks...')
    counts = np.zeros(n_classes, dtype=np.float64)
    for name in names:
        mask = cv2.imread(os.path.join(mask_dir, name), cv2.IMREAD_GRAYSCALE)
        if mask is None:
            continue
        for c in range(n_classes):
            counts[c] += np.sum(mask == c)

    total = counts.sum()
    # inverse-frequency weighting
    weights = total / (n_classes * (counts + 1e-6))
    # normalize: trung bình = 1
    weights = weights / weights.mean()

    print('Class pixel counts :', counts.astype(int))
    print('Class weights       :', np.round(weights, 4))
    return torch.tensor(weights, dtype=torch.float32).to(device)

# %% [markdown]
# ## Dataset

# %%
class Dataset(torch.utils.data.Dataset):

    def __init__(
        self,
        list_IDs,
        images_dir,
        masks_dir,
        augmentation=None,
        preprocessing=None,
        to_categorical=False,
        resize=(256, 256),
        n_classes=4,
        default_img=None,
        default_mask=None,
    ):
        self.ids          = list_IDs
        self.images_fps   = [os.path.join(images_dir, i) for i in list_IDs]
        self.masks_fps    = [os.path.join(masks_dir,  i) for i in list_IDs]
        self.augmentation  = augmentation
        self.preprocessing = preprocessing
        self.to_categorical = to_categorical
        self.resize        = resize
        self.n_classes     = n_classes
        self.default_img   = default_img
        self.default_mask  = default_mask

    def __len__(self):
        return len(self.ids)

    def __getitem__(self, i):
        image = cv2.imread(self.images_fps[i])
        mask  = cv2.imread(self.masks_fps[i],  cv2.IMREAD_GRAYSCALE)

        if image is None or mask is None:
            image = self.default_img.copy()
            mask  = self.default_mask.copy()
        else:
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        image = cv2.resize(image, self.resize, interpolation=cv2.INTER_LINEAR)
        mask  = cv2.resize(mask,  self.resize, interpolation=cv2.INTER_NEAREST)

        # clip mask về đúng range để tránh lỗi one-hot
        mask = np.clip(mask, 0, self.n_classes - 1)

        mask = np.expand_dims(mask, axis=-1)   # (H,W) → (H,W,1)

        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']

        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']

        if self.to_categorical:
            mask = mask.squeeze(0).astype('int64')          # (H,W)
            mask = np.eye(self.n_classes)[mask]             # (H,W,C)
            mask = np.transpose(mask, (2, 0, 1)).astype('float32')  # (C,H,W)

        return image, mask

# %% [markdown]
# ## Augmentation
#
# Thêm `ElasticTransform` và `CoarseDropout` so với baseline cũ để model robust hơn với vết thương có hình dạng bất thường.

# %%
def get_training_augmentation():
    train_transform = [

        # Flip
        albu.OneOf([
            albu.HorizontalFlip(p=0.5),
            albu.VerticalFlip(p=0.5),
        ], p=0.8),

        # Geometric
        albu.OneOf([
            albu.ShiftScaleRotate(scale_limit=0.5,  rotate_limit=0,  shift_limit=0,   p=0.1, border_mode=0),
            albu.ShiftScaleRotate(scale_limit=0,    rotate_limit=30, shift_limit=0,   p=0.1, border_mode=0),
            albu.ShiftScaleRotate(scale_limit=0,    rotate_limit=0,  shift_limit=0.1, p=0.6, border_mode=0),
            albu.ShiftScaleRotate(scale_limit=0.5,  rotate_limit=30, shift_limit=0.1, p=0.2, border_mode=0),
        ], p=0.9),

        # ✅ MỚI: Elastic transform — giúp model học được biên dạng vết thương phức tạp
        albu.ElasticTransform(
            alpha=120, sigma=6, p=0.3
        ),

        # Noise / Blur
        albu.OneOf([
            albu.Perspective(p=0.2),
            albu.GaussNoise(p=0.2),
            albu.Sharpen(p=0.2),
            albu.Blur(blur_limit=3, p=0.2),
            albu.MotionBlur(blur_limit=3, p=0.2),
        ], p=0.5),

        # Color
        albu.OneOf([
            albu.CLAHE(p=0.25),
            albu.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.25),
            albu.RandomGamma(p=0.25),
            albu.HueSaturationValue(p=0.25),
        ], p=0.3),

        # ✅ MỚI: CoarseDropout — giả lập vùng bị che khuất, giúp model không overfit
        albu.CoarseDropout(
            max_holes=8, max_height=16, max_width=16,
            min_holes=1, min_height=8,  min_width=8,
            fill_value=0, p=0.2
        ),

    ]
    return albu.Compose(train_transform, p=0.9)


def get_validation_augmentation():
    return albu.Compose([])


def to_tensor(x, **kwargs):
    return x.transpose(2, 0, 1).astype('float32')


def get_preprocessing(preprocessing_fn):
    _transform = [
        albu.Lambda(image=preprocessing_fn),
        albu.Lambda(image=to_tensor, mask=to_tensor),
    ]
    return albu.Compose(_transform)

# %% [markdown]
# ## Custom Focal Loss
#
# Focal Loss phạt nặng hơn các pixel bị predict sai trên class thiểu số (label 1). Kết hợp với class_weights để xử lý triệt để class imbalance.

# %%
class WeightedFocalLoss(nn.Module):
    """
    Focal Loss cho multiclass segmentation với class weights.
    Input : pred  (B, C, H, W) — logits hoặc softmax probs
            target (B, C, H, W) — one-hot float32
    """
    def __init__(self, gamma=2.0, weight=None, eps=1e-6):
        super().__init__()
        self.gamma  = gamma
        self.weight = weight   # Tensor shape (C,)
        self.eps    = eps

    def forward(self, pred, target):
        # pred: (B,C,H,W) sau softmax  |  target: (B,C,H,W) one-hot
        if pred.shape != target.shape:
            raise ValueError(f'Shape mismatch: pred {pred.shape} vs target {target.shape}')

        pred    = pred.clamp(self.eps, 1.0 - self.eps)
        log_p   = torch.log(pred)                         # (B,C,H,W)
        focal_w = (1.0 - pred) ** self.gamma              # (B,C,H,W)
        loss    = -focal_w * log_p * target               # (B,C,H,W)

        if self.weight is not None:
            # broadcast class weights: (C,) → (1,C,1,1)
            w = self.weight.view(1, -1, 1, 1).to(pred.device)
            loss = loss * w

        return loss.mean()


# Wrapper để tương thích với smp SumOfLosses
class FocalLossWrapper(base.Loss, nn.Module):
    def __init__(self, gamma=2.0, weight=None):
        nn.Module.__init__(self) # Initialize nn.Module first
        super().__init__(name='focal_loss') # Then base.Loss.__init__
        self._loss    = WeightedFocalLoss(gamma=gamma, weight=weight)

    def forward(self, pred, target):
        return self._loss(pred, target)

# %% [markdown]
# ## Setup paths & tính class weights

# %%
BASE_DATASET = os.path.join(PROJECT_ROOT, 'DFUTissue', 'Labeled', 'Padded')

x_train_dir = os.path.join(BASE_DATASET, 'Images',      'TrainVal')
y_train_dir = os.path.join(BASE_DATASET, 'Annotations', 'TrainVal')
x_valid_dir = x_train_dir
y_valid_dir = y_train_dir
x_test_dir  = os.path.join(BASE_DATASET, 'Images',      'Test')
y_test_dir  = os.path.join(BASE_DATASET, 'Annotations', 'Test')

dir_txt        = os.path.join(PROJECT_ROOT, 'DFUTissue', 'Labeled')
list_IDs_train = read_names(os.path.join(dir_txt, 'labeled_train_names.txt'), ext='.png')
list_IDs_val   = read_names(os.path.join(dir_txt, 'labeled_val_names.txt'),   ext='.png')
list_IDs_test  = read_names(os.path.join(dir_txt, 'test_names.txt'),          ext='.png')

print('Train :', len(list_IDs_train))
print('Val   :', len(list_IDs_val))
print('Test  :', len(list_IDs_test))

# ✅ Tính class weights từ training set
class_weights = compute_class_weights(y_train_dir, list_IDs_train, n_classes=n_classes, device=DEVICE)
# Out:
# Train : 78
# Val   : 16
# Test  : 16
# ⏳ Đang tính class weights từ training masks...
# Class pixel counts : [4719842   52037  103758  236171]
# Class weights       : [0.0254 2.3083 1.1577 0.5086]

# %% [markdown]
# ## Build model, loss, optimizer

# %%
seed = random.randint(0, 5000)
print(f'seed: {seed}')
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
np.random.seed(seed)
random.seed(seed)

# ================================================================
#  MODEL — Vanilla U-Net, không có attention
#  Chỉ thay encoder resnet34 → resnet50 để có capacity tốt hơn
# ================================================================
model = smp.Unet(
    encoder_name          = ENCODER,
    encoder_weights       = ENCODER_WEIGHTS,
    classes               = n_classes,
    activation            = ACTIVATION,
    decoder_attention_type= None,   # vanilla — không pscSE
)
model.to(DEVICE)

preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)

# ================================================================
#  LOSS
#  ✅ Dice + Weighted Focal (thay CE thuần)
#     Dice   : xử lý imbalance tốt ở cấp độ region
#     Focal  : phạt nặng class khó (label 1) ở cấp độ pixel
# ================================================================
dice_loss  = losses.DiceLoss()
focal_loss = FocalLossWrapper(gamma=FOCAL_GAMMA, weight=class_weights)
total_loss = base.SumOfLosses(dice_loss, focal_loss)

metrics_list = [
    smp.utils.metrics.IoU(threshold=0.5),
    smp.utils.metrics.Fscore(threshold=0.5),
]

# ================================================================
#  OPTIMIZER + SCHEDULER
#  ✅ AdamW (weight decay tách biệt khỏi gradient) thay Adam
#  ✅ CosineAnnealingWarmRestarts: tránh stuck local minima
# ================================================================
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=LR,
    weight_decay=WEIGHT_DECAY
)

# T_0: restart sau mỗi 50 epoch, T_mult=2: mỗi lần restart chu kỳ nhân đôi
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer, T_0=50, T_mult=2, eta_min=1e-6
)

total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'\nModel params : {total_params/1e6:.1f}M')
print(f'Loss         : DiceLoss + WeightedFocalLoss(gamma={FOCAL_GAMMA})')
print(f'Optimizer    : AdamW  lr={LR}  wd={WEIGHT_DECAY}')
print(f'Scheduler    : CosineAnnealingWarmRestarts T0=50 Tmult=2')
# Out:
# seed: 4199
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 296MB/s]
# Model params : 75.9M
# Loss         : DiceLoss + WeightedFocalLoss(gamma=2.0)
# Optimizer    : AdamW  lr=0.0001  wd=0.0001
# Scheduler    : CosineAnnealingWarmRestarts T0=50 Tmult=2

# %% [markdown]
# ## Dataloader

# %%
random.shuffle(list_IDs_train)

DEFAULT_IMG_TRAIN  = cv2.cvtColor(cv2.imread(os.path.join(x_train_dir, list_IDs_train[0])), cv2.COLOR_BGR2RGB)
DEFAULT_MASK_TRAIN = cv2.imread(os.path.join(y_train_dir, list_IDs_train[0]), 0)
DEFAULT_IMG_VAL    = cv2.cvtColor(cv2.imread(os.path.join(x_valid_dir, list_IDs_val[0])),   cv2.COLOR_BGR2RGB)
DEFAULT_MASK_VAL   = cv2.imread(os.path.join(y_valid_dir, list_IDs_val[0]), 0)

train_dataset = Dataset(
    list_IDs_train, x_train_dir, y_train_dir,
    augmentation  = get_training_augmentation(),
    preprocessing = get_preprocessing(preprocessing_fn),
    to_categorical= TO_CATEGORICAL,
    resize=RESIZE, n_classes=n_classes,
    default_img=DEFAULT_IMG_TRAIN, default_mask=DEFAULT_MASK_TRAIN,
)

valid_dataset = Dataset(
    list_IDs_val, x_valid_dir, y_valid_dir,
    augmentation  = get_validation_augmentation(),
    preprocessing = get_preprocessing(preprocessing_fn),
    to_categorical= TO_CATEGORICAL,
    resize=RESIZE, n_classes=n_classes,
    default_img=DEFAULT_IMG_VAL, default_mask=DEFAULT_MASK_VAL,
)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,  num_workers=2, pin_memory=True)
valid_loader = DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)

print(f'Train batches : {len(train_loader)}')
print(f'Val   batches : {len(valid_loader)}')
# Out:
# Train batches : 10
# Val   batches : 2

# %% [markdown]
# ## Training

# %%
USE_TTA = False # Set to True if you want to use Test Time Augmentation

# %%
model_name     = BASE_MODEL + '_' + datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
checkpoint_loc = os.path.join(PROJECT_ROOT, 'checkpoints', model_name)
os.makedirs(checkpoint_loc, exist_ok=True)
print('Model name :', model_name)

train_epoch = smp.utils.train.TrainEpoch(
    model, loss=total_loss, metrics=metrics_list,
    optimizer=optimizer, device=DEVICE, verbose=True,
)
valid_epoch = smp.utils.train.ValidEpoch(
    model, loss=total_loss, metrics=metrics_list,
    device=DEVICE, verbose=True,
)

best_viou    = 0.0
best_vloss   = 1_000_000.
save_model   = False
cnt_patience = 0
best_model_epoch = 0

store_train_loss, store_val_loss   = [], []
store_train_iou,  store_val_iou    = [], []
store_train_dice, store_val_dice   = [], []
store_lr                           = []

for epoch in range(EPOCHS):

    current_lr = optimizer.param_groups[0]['lr']
    print(f'\nEpoch {epoch:04d}  |  LR = {current_lr:.2e}')

    train_logs = train_epoch.run(train_loader)
    valid_logs = valid_epoch.run(valid_loader)

    train_loss_key = list(train_logs.keys())[0]
    val_loss_key   = list(valid_logs.keys())[0]

    store_train_loss.append(train_logs[train_loss_key])
    store_val_loss.append(valid_logs[val_loss_key])
    store_train_iou.append(train_logs['iou_score'])
    store_val_iou.append(valid_logs['iou_score'])
    store_train_dice.append(train_logs['fscore'])
    store_val_dice.append(valid_logs['fscore'])
    store_lr.append(current_lr)

    improved = False
    if valid_logs[val_loss_key] < best_vloss:
        best_vloss = valid_logs[val_loss_key]
        improved   = True
        print(f'  ✅ Val loss ↓  → {best_vloss:.4f}  (epoch {epoch:04d})')

    if valid_logs['iou_score'] > best_viou:
        best_viou = valid_logs['iou_score']
        improved  = True
        print(f'  ✅ Val IoU  ↑  → {best_viou:.4f}  (epoch {epoch:04d})')

    if improved:
        cnt_patience     = 0
        best_model_epoch = epoch
        save_checkpoint(
            os.path.join(checkpoint_loc, 'best_model.pth'),
            epoch, model.state_dict(), optimizer.state_dict()
        )
    else:
        cnt_patience += 1

    # Scheduler step
    scheduler.step(epoch)

    if EARLY_STOP and cnt_patience >= PATIENCE:
        print(f'\n⛔ Early stopping at epoch {epoch:04d}  (patience={PATIENCE})')
        break

    if not SAVE_BEST_MODEL and (epoch + 1) % PERIOD == 0:
        save_checkpoint(
            os.path.join(checkpoint_loc, f'cp-{epoch+1:04d}.pth'),
            epoch, model.state_dict(), optimizer.state_dict()
        )

if not EARLY_STOP and SAVE_LAST_MODEL:
    save_checkpoint(
        os.path.join(checkpoint_loc, 'last_model.pth'),
        epoch, model.state_dict(), optimizer.state_dict()
    )

print(f'\n🏆 Best model epoch : {best_model_epoch}')
# Out:
# Model name : UNet_resnet50_improved_2026-05-06_01-59-39
#
# Epoch 0000  |  LR = 1.00e-04
# train: 100%|██████████| 10/10 [00:18<00:00,  1.86s/it, dice_loss + focal_loss - 0.7138, iou_score - 0.1079, fscore - 0.1873]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.69s/it, dice_loss + focal_loss - 0.6456, iou_score - 0.2902, fscore - 0.4498]
#   ✅ Val loss ↓  → 0.6456  (epoch 0000)
#   ✅ Val IoU  ↑  → 0.2902  (epoch 0000)
#
# Epoch 0001  |  LR = 1.00e-04
# train: 100%|██████████| 10/10 [00:03<00:00,  2.97it/s, dice_loss + focal_loss - 0.5904, iou_score - 0.4166, fscore - 0.5869]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.20it/s, dice_loss + focal_loss - 0.5553, iou_score - 0.5355, fscore - 0.697]
#   ✅ Val loss ↓  → 0.5553  (epoch 0001)
#   ✅ Val IoU  ↑  → 0.5355  (epoch 0001)
#
# Epoch 0002  |  LR = 9.99e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.14it/s, dice_loss + focal_loss - 0.526, iou_score - 0.5869, fscore - 0.7392]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.79it/s, dice_loss + focal_loss - 0.5113, iou_score - 0.6224, fscore - 0.7667]
#   ✅ Val loss ↓  → 0.5113  (epoch 0002)
#   ✅ Val IoU  ↑  → 0.6224  (epoch 0002)
#
# Epoch 0003  |  LR = 9.96e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.96it/s, dice_loss + focal_loss - 0.4799, iou_score - 0.6536, fscore - 0.7898]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.00it/s, dice_loss + focal_loss - 0.4609, iou_score - 0.6534, fscore - 0.79]
#   ✅ Val loss ↓  → 0.4609  (epoch 0003)
#   ✅ Val IoU  ↑  → 0.6534  (epoch 0003)
#
# Epoch 0004  |  LR = 9.91e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.75it/s, dice_loss + focal_loss - 0.4499, iou_score - 0.6934, fscore - 0.8182]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.09it/s, dice_loss + focal_loss - 0.4314, iou_score - 0.6978, fscore - 0.8217]
#   ✅ Val loss ↓  → 0.4314  (epoch 0004)
#   ✅ Val IoU  ↑  → 0.6978  (epoch 0004)
#
# Epoch 0005  |  LR = 9.84e-05
# train: 100%|██████████| 10/10 [00:02<00:00,  3.39it/s, dice_loss + focal_loss - 0.4155, iou_score - 0.7484, fscore - 0.856]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.10it/s, dice_loss + focal_loss - 0.3881, iou_score - 0.7787, fscore - 0.8754]
#   ✅ Val loss ↓  → 0.3881  (epoch 0005)
#   ✅ Val IoU  ↑  → 0.7787  (epoch 0005)
#
# Epoch 0006  |  LR = 9.76e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.93it/s, dice_loss + focal_loss - 0.3911, iou_score - 0.7825, fscore - 0.8777]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.01it/s, dice_loss + focal_loss - 0.38, iou_score - 0.7919, fscore - 0.8835]
#   ✅ Val loss ↓  → 0.3800  (epoch 0006)
#   ✅ Val IoU  ↑  → 0.7919  (epoch 0006)
#
# Epoch 0007  |  LR = 9.65e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.81it/s, dice_loss + focal_loss - 0.3641, iou_score - 0.8125, fscore - 0.8964]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.11it/s, dice_loss + focal_loss - 0.3386, iou_score - 0.8642, fscore - 0.927]
#   ✅ Val loss ↓  → 0.3386  (epoch 0007)
#   ✅ Val IoU  ↑  → 0.8642  (epoch 0007)
#
# Epoch 0008  |  LR = 9.53e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.74it/s, dice_loss + focal_loss - 0.3437, iou_score - 0.8341, fscore - 0.9092]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.92it/s, dice_loss + focal_loss - 0.3325, iou_score - 0.8631, fscore - 0.9264]
#   ✅ Val loss ↓  → 0.3325  (epoch 0008)
#
# Epoch 0009  |  LR = 9.39e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.93it/s, dice_loss + focal_loss - 0.3183, iou_score - 0.8492, fscore - 0.9184]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.72it/s, dice_loss + focal_loss - 0.2908, iou_score - 0.8974, fscore - 0.9459]
#   ✅ Val loss ↓  → 0.2908  (epoch 0009)
#   ✅ Val IoU  ↑  → 0.8974  (epoch 0009)
#
# Epoch 0010  |  LR = 9.23e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.57it/s, dice_loss + focal_loss - 0.3047, iou_score - 0.8704, fscore - 0.9304]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s, dice_loss + focal_loss - 0.2881, iou_score - 0.8667, fscore - 0.9286]
#   ✅ Val loss ↓  → 0.2881  (epoch 0010)
#
# Epoch 0011  |  LR = 9.05e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.71it/s, dice_loss + focal_loss - 0.2827, iou_score - 0.8665, fscore - 0.9284]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s, dice_loss + focal_loss - 0.2736, iou_score - 0.8886, fscore - 0.941]
#   ✅ Val loss ↓  → 0.2736  (epoch 0011)
#
# Epoch 0012  |  LR = 8.86e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.91it/s, dice_loss + focal_loss - 0.2691, iou_score - 0.8783, fscore - 0.9351]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.05it/s, dice_loss + focal_loss - 0.2406, iou_score - 0.9009, fscore - 0.9478]
#   ✅ Val loss ↓  → 0.2406  (epoch 0012)
#   ✅ Val IoU  ↑  → 0.9009  (epoch 0012)
#
# Epoch 0013  |  LR = 8.66e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.76it/s, dice_loss + focal_loss - 0.2521, iou_score - 0.8893, fscore - 0.9413]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.22it/s, dice_loss + focal_loss - 0.2354, iou_score - 0.9128, fscore - 0.9544]
#   ✅ Val loss ↓  → 0.2354  (epoch 0013)
#   ✅ Val IoU  ↑  → 0.9128  (epoch 0013)
#
# Epoch 0014  |  LR = 8.44e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.67it/s, dice_loss + focal_loss - 0.2423, iou_score - 0.8845, fscore - 0.9385]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.74it/s, dice_loss + focal_loss - 0.2252, iou_score - 0.9023, fscore - 0.9486]
#   ✅ Val loss ↓  → 0.2252  (epoch 0014)
#
# Epoch 0015  |  LR = 8.21e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.09it/s, dice_loss + focal_loss - 0.2311, iou_score - 0.8978, fscore - 0.9461]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.91it/s, dice_loss + focal_loss - 0.2134, iou_score - 0.9082, fscore - 0.9518]
#   ✅ Val loss ↓  → 0.2134  (epoch 0015)
#
# Epoch 0016  |  LR = 7.96e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.93it/s, dice_loss + focal_loss - 0.2189, iou_score - 0.8963, fscore - 0.9453]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.03it/s, dice_loss + focal_loss - 0.2158, iou_score - 0.8973, fscore - 0.9457]
#
# Epoch 0017  |  LR = 7.70e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.05it/s, dice_loss + focal_loss - 0.2123, iou_score - 0.9003, fscore - 0.9475]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.32it/s, dice_loss + focal_loss - 0.1989, iou_score - 0.9114, fscore - 0.9535]
#   ✅ Val loss ↓  → 0.1989  (epoch 0017)
#
# Epoch 0018  |  LR = 7.43e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.65it/s, dice_loss + focal_loss - 0.2008, iou_score - 0.9033, fscore - 0.9491]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.99it/s, dice_loss + focal_loss - 0.186, iou_score - 0.9215, fscore - 0.9591]
#   ✅ Val loss ↓  → 0.1860  (epoch 0018)
#   ✅ Val IoU  ↑  → 0.9215  (epoch 0018)
#
# Epoch 0019  |  LR = 7.16e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.80it/s, dice_loss + focal_loss - 0.1896, iou_score - 0.9144, fscore - 0.9553]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.11it/s, dice_loss + focal_loss - 0.1807, iou_score - 0.9225, fscore - 0.9597]
#   ✅ Val loss ↓  → 0.1807  (epoch 0019)
#   ✅ Val IoU  ↑  → 0.9225  (epoch 0019)
#
# Epoch 0020  |  LR = 6.87e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.18it/s, dice_loss + focal_loss - 0.1826, iou_score - 0.918, fscore - 0.9571]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.16it/s, dice_loss + focal_loss - 0.1756, iou_score - 0.9261, fscore - 0.9616]
#   ✅ Val loss ↓  → 0.1756  (epoch 0020)
#   ✅ Val IoU  ↑  → 0.9261  (epoch 0020)
#
# Epoch 0021  |  LR = 6.58e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.73it/s, dice_loss + focal_loss - 0.1791, iou_score - 0.9115, fscore - 0.9536]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.05it/s, dice_loss + focal_loss - 0.1712, iou_score - 0.919, fscore - 0.9578]
#   ✅ Val loss ↓  → 0.1712  (epoch 0021)
#
# Epoch 0022  |  LR = 6.28e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.88it/s, dice_loss + focal_loss - 0.1732, iou_score - 0.9135, fscore - 0.9547]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.09it/s, dice_loss + focal_loss - 0.1678, iou_score - 0.9214, fscore - 0.9591]
#   ✅ Val loss ↓  → 0.1678  (epoch 0022)
#
# Epoch 0023  |  LR = 5.98e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.08it/s, dice_loss + focal_loss - 0.1669, iou_score - 0.9265, fscore - 0.9617]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.90it/s, dice_loss + focal_loss - 0.1682, iou_score - 0.9083, fscore - 0.952]
#
# Epoch 0024  |  LR = 5.67e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.77it/s, dice_loss + focal_loss - 0.1662, iou_score - 0.9105, fscore - 0.9531]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.43it/s, dice_loss + focal_loss - 0.1637, iou_score - 0.9123, fscore - 0.9541]
#   ✅ Val loss ↓  → 0.1637  (epoch 0024)
#
# Epoch 0025  |  LR = 5.36e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.51it/s, dice_loss + focal_loss - 0.1578, iou_score - 0.9197, fscore - 0.9581]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.29it/s, dice_loss + focal_loss - 0.153, iou_score - 0.9191, fscore - 0.9578]
#   ✅ Val loss ↓  → 0.1530  (epoch 0025)
#
# Epoch 0026  |  LR = 5.05e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.78it/s, dice_loss + focal_loss - 0.1546, iou_score - 0.9209, fscore - 0.9587]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.19it/s, dice_loss + focal_loss - 0.1525, iou_score - 0.9134, fscore - 0.9547]
#   ✅ Val loss ↓  → 0.1525  (epoch 0026)
#
# Epoch 0027  |  LR = 4.74e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.63it/s, dice_loss + focal_loss - 0.1513, iou_score - 0.9188, fscore - 0.9576]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.70it/s, dice_loss + focal_loss - 0.1507, iou_score - 0.9197, fscore - 0.9581]
#   ✅ Val loss ↓  → 0.1507  (epoch 0027)
#
# Epoch 0028  |  LR = 4.43e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.87it/s, dice_loss + focal_loss - 0.1466, iou_score - 0.9258, fscore - 0.9615]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.43it/s, dice_loss + focal_loss - 0.1453, iou_score - 0.9184, fscore - 0.9575]
#   ✅ Val loss ↓  → 0.1453  (epoch 0028)
#
# Epoch 0029  |  LR = 4.12e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.85it/s, dice_loss + focal_loss - 0.1427, iou_score - 0.9262, fscore - 0.9616]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s, dice_loss + focal_loss - 0.1453, iou_score - 0.9156, fscore - 0.956]
#
# Epoch 0030  |  LR = 3.82e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.18it/s, dice_loss + focal_loss - 0.1409, iou_score - 0.9282, fscore - 0.9625]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.96it/s, dice_loss + focal_loss - 0.1425, iou_score - 0.9208, fscore - 0.9587]
#   ✅ Val loss ↓  → 0.1425  (epoch 0030)
#
# Epoch 0031  |  LR = 3.52e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.83it/s, dice_loss + focal_loss - 0.1365, iou_score - 0.9315, fscore - 0.9645]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.15it/s, dice_loss + focal_loss - 0.1385, iou_score - 0.9284, fscore - 0.9628]
#   ✅ Val loss ↓  → 0.1385  (epoch 0031)
#   ✅ Val IoU  ↑  → 0.9284  (epoch 0031)
#
# Epoch 0032  |  LR = 3.23e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.81it/s, dice_loss + focal_loss - 0.1386, iou_score - 0.9299, fscore - 0.9635]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.04it/s, dice_loss + focal_loss - 0.1372, iou_score - 0.9231, fscore - 0.96]
#   ✅ Val loss ↓  → 0.1372  (epoch 0032)
#
# Epoch 0033  |  LR = 2.94e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.83it/s, dice_loss + focal_loss - 0.13, iou_score - 0.9347, fscore - 0.9662]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.97it/s, dice_loss + focal_loss - 0.1347, iou_score - 0.9235, fscore - 0.9602]
#   ✅ Val loss ↓  → 0.1347  (epoch 0033)
#
# Epoch 0034  |  LR = 2.67e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.16it/s, dice_loss + focal_loss - 0.1349, iou_score - 0.929, fscore - 0.963]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.23it/s, dice_loss + focal_loss - 0.1345, iou_score - 0.926, fscore - 0.9616]
#   ✅ Val loss ↓  → 0.1345  (epoch 0034)
#
# Epoch 0035  |  LR = 2.40e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.63it/s, dice_loss + focal_loss - 0.1276, iou_score - 0.9335, fscore - 0.9656]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.01it/s, dice_loss + focal_loss - 0.1316, iou_score - 0.9255, fscore - 0.9613]
#   ✅ Val loss ↓  → 0.1316  (epoch 0035)
#
# Epoch 0036  |  LR = 2.14e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.89it/s, dice_loss + focal_loss - 0.1287, iou_score - 0.9325, fscore - 0.965]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.96it/s, dice_loss + focal_loss - 0.13, iou_score - 0.9282, fscore - 0.9628]
#   ✅ Val loss ↓  → 0.1300  (epoch 0036)
#
# Epoch 0037  |  LR = 1.89e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.90it/s, dice_loss + focal_loss - 0.1238, iou_score - 0.9371, fscore - 0.9675]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.97it/s, dice_loss + focal_loss - 0.1299, iou_score - 0.9259, fscore - 0.9615]
#   ✅ Val loss ↓  → 0.1299  (epoch 0037)
#
# Epoch 0038  |  LR = 1.66e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.18it/s, dice_loss + focal_loss - 0.1254, iou_score - 0.9329, fscore - 0.9652]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s, dice_loss + focal_loss - 0.1269, iou_score - 0.9306, fscore - 0.964]
#   ✅ Val loss ↓  → 0.1269  (epoch 0038)
#   ✅ Val IoU  ↑  → 0.9306  (epoch 0038)
#
# Epoch 0039  |  LR = 1.44e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.67it/s, dice_loss + focal_loss - 0.1214, iou_score - 0.941, fscore - 0.9696]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.97it/s, dice_loss + focal_loss - 0.1269, iou_score - 0.9302, fscore - 0.9638]
#
# Epoch 0040  |  LR = 1.24e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.16it/s, dice_loss + focal_loss - 0.1276, iou_score - 0.9321, fscore - 0.9648]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.27it/s, dice_loss + focal_loss - 0.1275, iou_score - 0.9253, fscore - 0.9612]
#
# Epoch 0041  |  LR = 1.05e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.05it/s, dice_loss + focal_loss - 0.1228, iou_score - 0.9341, fscore - 0.9659]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.34it/s, dice_loss + focal_loss - 0.1276, iou_score - 0.9228, fscore - 0.9598]
#
# Epoch 0042  |  LR = 8.71e-06
# train: 100%|██████████| 10/10 [00:04<00:00,  2.42it/s, dice_loss + focal_loss - 0.1243, iou_score - 0.9335, fscore - 0.9655]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.31s/it, dice_loss + focal_loss - 0.1254, iou_score - 0.9274, fscore - 0.9623]
#   ✅ Val loss ↓  → 0.1254  (epoch 0042)
#
# Epoch 0043  |  LR = 7.12e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  2.59it/s, dice_loss + focal_loss - 0.1209, iou_score - 0.9381, fscore - 0.968]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.20it/s, dice_loss + focal_loss - 0.1265, iou_score - 0.9266, fscore - 0.9619]
#
# Epoch 0044  |  LR = 5.71e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  3.03it/s, dice_loss + focal_loss - 0.12, iou_score - 0.9387, fscore - 0.9684]
# valid: 100%|██████████| 2/2 [00:13<00:00,  6.55s/it, dice_loss + focal_loss - 0.1267, iou_score - 0.9258, fscore - 0.9615]
#
# Epoch 0045  |  LR = 4.48e-06
# train: 100%|██████████| 10/10 [00:14<00:00,  1.47s/it, dice_loss + focal_loss - 0.1198, iou_score - 0.9393, fscore - 0.9686]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.78it/s, dice_loss + focal_loss - 0.1257, iou_score - 0.9272, fscore - 0.9622]
#
# Epoch 0046  |  LR = 3.42e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  3.07it/s, dice_loss + focal_loss - 0.1168, iou_score - 0.9431, fscore - 0.9707]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.91it/s, dice_loss + focal_loss - 0.1256, iou_score - 0.9273, fscore - 0.9623]
#
# Epoch 0047  |  LR = 2.56e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  3.10it/s, dice_loss + focal_loss - 0.1202, iou_score - 0.9362, fscore - 0.967]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.79it/s, dice_loss + focal_loss - 0.1249, iou_score - 0.9255, fscore - 0.9613]
#   ✅ Val loss ↓  → 0.1249  (epoch 0047)
#
# Epoch 0048  |  LR = 1.88e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  2.85it/s, dice_loss + focal_loss - 0.1197, iou_score - 0.9381, fscore - 0.968]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.88it/s, dice_loss + focal_loss - 0.1254, iou_score - 0.9241, fscore - 0.9605]
#
# Epoch 0049  |  LR = 1.39e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  3.05it/s, dice_loss + focal_loss - 0.1232, iou_score - 0.9329, fscore - 0.9652]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.02it/s, dice_loss + focal_loss - 0.1258, iou_score - 0.9237, fscore - 0.9603]
#
# Epoch 0050  |  LR = 1.10e-06
# train: 100%|██████████| 10/10 [00:25<00:00,  2.60s/it, dice_loss + focal_loss - 0.121, iou_score - 0.9355, fscore - 0.9666]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.26it/s, dice_loss + focal_loss - 0.127, iou_score - 0.9214, fscore - 0.9591]
#
# Epoch 0051  |  LR = 1.00e-04
# train: 100%|██████████| 10/10 [00:04<00:00,  2.50it/s, dice_loss + focal_loss - 0.1252, iou_score - 0.9268, fscore - 0.9618]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.64it/s, dice_loss + focal_loss - 0.1279, iou_score - 0.9133, fscore - 0.9546]
#
# Epoch 0052  |  LR = 1.00e-04
# train: 100%|██████████| 10/10 [00:03<00:00,  3.24it/s, dice_loss + focal_loss - 0.1256, iou_score - 0.9235, fscore - 0.96]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.28it/s, dice_loss + focal_loss - 0.1247, iou_score - 0.9106, fscore - 0.9531]
#   ✅ Val loss ↓  → 0.1247  (epoch 0052)
#
# Epoch 0053  |  LR = 9.99e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.07it/s, dice_loss + focal_loss - 0.1212, iou_score - 0.9201, fscore - 0.9583]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.96it/s, dice_loss + focal_loss - 0.1191, iou_score - 0.9284, fscore - 0.9628]
#   ✅ Val loss ↓  → 0.1191  (epoch 0053)
#
# Epoch 0054  |  LR = 9.98e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.96it/s, dice_loss + focal_loss - 0.1181, iou_score - 0.9206, fscore - 0.9586]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.83it/s, dice_loss + focal_loss - 0.1076, iou_score - 0.924, fscore - 0.9604]
#   ✅ Val loss ↓  → 0.1076  (epoch 0054)
#
# Epoch 0055  |  LR = 9.96e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.86it/s, dice_loss + focal_loss - 0.1096, iou_score - 0.9278, fscore - 0.9625]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.93it/s, dice_loss + focal_loss - 0.104, iou_score - 0.936, fscore - 0.9669]
#   ✅ Val loss ↓  → 0.1040  (epoch 0055)
#   ✅ Val IoU  ↑  → 0.9360  (epoch 0055)
#
# Epoch 0056  |  LR = 9.94e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.72it/s, dice_loss + focal_loss - 0.1051, iou_score - 0.9311, fscore - 0.9643]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.94it/s, dice_loss + focal_loss - 0.1152, iou_score - 0.9027, fscore - 0.9489]
#
# Epoch 0057  |  LR = 9.91e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.16it/s, dice_loss + focal_loss - 0.1051, iou_score - 0.9259, fscore - 0.9614]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.93it/s, dice_loss + focal_loss - 0.1048, iou_score - 0.9344, fscore - 0.966]
#
# Epoch 0058  |  LR = 9.88e-05
# train: 100%|██████████| 10/10 [00:27<00:00,  2.73s/it, dice_loss + focal_loss - 0.09953, iou_score - 0.9319, fscore - 0.9646]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.48it/s, dice_loss + focal_loss - 0.1078, iou_score - 0.9117, fscore - 0.9538]
#
# Epoch 0059  |  LR = 9.84e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.13it/s, dice_loss + focal_loss - 0.0984, iou_score - 0.9289, fscore - 0.9631]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.94it/s, dice_loss + focal_loss - 0.09495, iou_score - 0.9374, fscore - 0.9677]
#   ✅ Val loss ↓  → 0.0949  (epoch 0059)
#   ✅ Val IoU  ↑  → 0.9374  (epoch 0059)
#
# Epoch 0060  |  LR = 9.80e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.00it/s, dice_loss + focal_loss - 0.09522, iou_score - 0.9284, fscore - 0.9628]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.12it/s, dice_loss + focal_loss - 0.08983, iou_score - 0.9374, fscore - 0.9677]
#   ✅ Val loss ↓  → 0.0898  (epoch 0060)
#   ✅ Val IoU  ↑  → 0.9374  (epoch 0060)
#
# Epoch 0061  |  LR = 9.76e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.69it/s, dice_loss + focal_loss - 0.09438, iou_score - 0.93, fscore - 0.9637]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.08it/s, dice_loss + focal_loss - 0.08755, iou_score - 0.9348, fscore - 0.9663]
#   ✅ Val loss ↓  → 0.0875  (epoch 0061)
#
# Epoch 0062  |  LR = 9.71e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.75it/s, dice_loss + focal_loss - 0.09099, iou_score - 0.9336, fscore - 0.9656]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.81it/s, dice_loss + focal_loss - 0.08729, iou_score - 0.9339, fscore - 0.9658]
#   ✅ Val loss ↓  → 0.0873  (epoch 0062)
#
# Epoch 0063  |  LR = 9.65e-05
# train: 100%|██████████| 10/10 [00:04<00:00,  2.44it/s, dice_loss + focal_loss - 0.08481, iou_score - 0.9384, fscore - 0.9682]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.87it/s, dice_loss + focal_loss - 0.08585, iou_score - 0.9389, fscore - 0.9685]
#   ✅ Val loss ↓  → 0.0859  (epoch 0063)
#   ✅ Val IoU  ↑  → 0.9389  (epoch 0063)
#
# Epoch 0064  |  LR = 9.59e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.72it/s, dice_loss + focal_loss - 0.08693, iou_score - 0.9308, fscore - 0.9639]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.09it/s, dice_loss + focal_loss - 0.08093, iou_score - 0.934, fscore - 0.9659]
#   ✅ Val loss ↓  → 0.0809  (epoch 0064)
#
# Epoch 0065  |  LR = 9.53e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.60it/s, dice_loss + focal_loss - 0.09043, iou_score - 0.9305, fscore - 0.9639]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.10it/s, dice_loss + focal_loss - 0.07915, iou_score - 0.9384, fscore - 0.9682]
#   ✅ Val loss ↓  → 0.0791  (epoch 0065)
#
# Epoch 0066  |  LR = 9.46e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.98it/s, dice_loss + focal_loss - 0.08101, iou_score - 0.9355, fscore - 0.9666]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.92it/s, dice_loss + focal_loss - 0.08027, iou_score - 0.9345, fscore - 0.9661]
#
# Epoch 0067  |  LR = 9.39e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.19it/s, dice_loss + focal_loss - 0.08113, iou_score - 0.9332, fscore - 0.9654]
# valid: 100%|██████████| 2/2 [00:13<00:00,  6.58s/it, dice_loss + focal_loss - 0.08759, iou_score - 0.9157, fscore - 0.9559]
#
# Epoch 0068  |  LR = 9.31e-05
# train: 100%|██████████| 10/10 [00:14<00:00,  1.47s/it, dice_loss + focal_loss - 0.0737, iou_score - 0.9458, fscore - 0.9721]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.67it/s, dice_loss + focal_loss - 0.07916, iou_score - 0.9318, fscore - 0.9647]
#
# Epoch 0069  |  LR = 9.23e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.53it/s, dice_loss + focal_loss - 0.07394, iou_score - 0.9408, fscore - 0.9695]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.02it/s, dice_loss + focal_loss - 0.07886, iou_score - 0.9297, fscore - 0.9635]
#   ✅ Val loss ↓  → 0.0789  (epoch 0069)
#
# Epoch 0070  |  LR = 9.14e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.79it/s, dice_loss + focal_loss - 0.07298, iou_score - 0.94, fscore - 0.969]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.98it/s, dice_loss + focal_loss - 0.07281, iou_score - 0.9409, fscore - 0.9696]
#   ✅ Val loss ↓  → 0.0728  (epoch 0070)
#   ✅ Val IoU  ↑  → 0.9409  (epoch 0070)
#
# Epoch 0071  |  LR = 9.05e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.56it/s, dice_loss + focal_loss - 0.07136, iou_score - 0.9434, fscore - 0.9708]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.13it/s, dice_loss + focal_loss - 0.07603, iou_score - 0.932, fscore - 0.9648]
#
# Epoch 0072  |  LR = 8.96e-05
# train: 100%|██████████| 10/10 [00:15<00:00,  1.55s/it, dice_loss + focal_loss - 0.07247, iou_score - 0.9387, fscore - 0.9683]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.06it/s, dice_loss + focal_loss - 0.07656, iou_score - 0.9282, fscore - 0.9627]
#
# Epoch 0073  |  LR = 8.86e-05
# train: 100%|██████████| 10/10 [00:14<00:00,  1.47s/it, dice_loss + focal_loss - 0.06845, iou_score - 0.9449, fscore - 0.9716]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.41it/s, dice_loss + focal_loss - 0.0741, iou_score - 0.9296, fscore - 0.9635]
#
# Epoch 0074  |  LR = 8.76e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.16it/s, dice_loss + focal_loss - 0.06963, iou_score - 0.9409, fscore - 0.9694]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.71it/s, dice_loss + focal_loss - 0.07134, iou_score - 0.9327, fscore - 0.9652]
#   ✅ Val loss ↓  → 0.0713  (epoch 0074)
#
# Epoch 0075  |  LR = 8.66e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.90it/s, dice_loss + focal_loss - 0.06828, iou_score - 0.9448, fscore - 0.9715]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.18it/s, dice_loss + focal_loss - 0.07065, iou_score - 0.9388, fscore - 0.9684]
#   ✅ Val loss ↓  → 0.0707  (epoch 0075)
#
# Epoch 0076  |  LR = 8.55e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.82it/s, dice_loss + focal_loss - 0.06817, iou_score - 0.942, fscore - 0.97]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.08it/s, dice_loss + focal_loss - 0.07399, iou_score - 0.923, fscore - 0.96]
#
# Epoch 0077  |  LR = 8.44e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.15it/s, dice_loss + focal_loss - 0.06575, iou_score - 0.9449, fscore - 0.9716]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.94it/s, dice_loss + focal_loss - 0.06985, iou_score - 0.9372, fscore - 0.9676]
#   ✅ Val loss ↓  → 0.0699  (epoch 0077)
#
# Epoch 0078  |  LR = 8.32e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.83it/s, dice_loss + focal_loss - 0.06789, iou_score - 0.9398, fscore - 0.9689]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.93it/s, dice_loss + focal_loss - 0.06519, iou_score - 0.9394, fscore - 0.9687]
#   ✅ Val loss ↓  → 0.0652  (epoch 0078)
#
# Epoch 0079  |  LR = 8.21e-05
# train: 100%|██████████| 10/10 [00:04<00:00,  2.41it/s, dice_loss + focal_loss - 0.06541, iou_score - 0.9441, fscore - 0.9712]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.96it/s, dice_loss + focal_loss - 0.06784, iou_score - 0.934, fscore - 0.9659]
#
# Epoch 0080  |  LR = 8.08e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.19it/s, dice_loss + focal_loss - 0.06236, iou_score - 0.944, fscore - 0.9711]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.67it/s, dice_loss + focal_loss - 0.06631, iou_score - 0.9382, fscore - 0.9681]
#
# Epoch 0081  |  LR = 7.96e-05
# train: 100%|██████████| 10/10 [00:14<00:00,  1.48s/it, dice_loss + focal_loss - 0.06163, iou_score - 0.9467, fscore - 0.9726]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.73it/s, dice_loss + focal_loss - 0.06604, iou_score - 0.9363, fscore - 0.9671]
#
# Epoch 0082  |  LR = 7.83e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.16it/s, dice_loss + focal_loss - 0.06146, iou_score - 0.9472, fscore - 0.9728]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.69it/s, dice_loss + focal_loss - 0.06841, iou_score - 0.9264, fscore - 0.9618]
#
# Epoch 0083  |  LR = 7.70e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.60it/s, dice_loss + focal_loss - 0.05803, iou_score - 0.9485, fscore - 0.9735]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.94it/s, dice_loss + focal_loss - 0.0658, iou_score - 0.9402, fscore - 0.9692]
#
# Epoch 0084  |  LR = 7.57e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.07it/s, dice_loss + focal_loss - 0.05998, iou_score - 0.949, fscore - 0.9737]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.63it/s, dice_loss + focal_loss - 0.07034, iou_score - 0.923, fscore - 0.9599]
#
# Epoch 0085  |  LR = 7.43e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.09it/s, dice_loss + focal_loss - 0.05773, iou_score - 0.9471, fscore - 0.9728]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.96it/s, dice_loss + focal_loss - 0.06496, iou_score - 0.9368, fscore - 0.9674]
#   ✅ Val loss ↓  → 0.0650  (epoch 0085)
#
# Epoch 0086  |  LR = 7.30e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.88it/s, dice_loss + focal_loss - 0.05357, iou_score - 0.9554, fscore - 0.9772]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.89it/s, dice_loss + focal_loss - 0.06495, iou_score - 0.9366, fscore - 0.9673]
#   ✅ Val loss ↓  → 0.0649  (epoch 0086)
#
# Epoch 0087  |  LR = 7.16e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.96it/s, dice_loss + focal_loss - 0.05633, iou_score - 0.9494, fscore - 0.974]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.33it/s, dice_loss + focal_loss - 0.06268, iou_score - 0.9372, fscore - 0.9676]
#   ✅ Val loss ↓  → 0.0627  (epoch 0087)
#
# Epoch 0088  |  LR = 7.02e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.98it/s, dice_loss + focal_loss - 0.05585, iou_score - 0.9499, fscore - 0.9743]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.87it/s, dice_loss + focal_loss - 0.06355, iou_score - 0.9334, fscore - 0.9656]
#
# Epoch 0089  |  LR = 6.87e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.23it/s, dice_loss + focal_loss - 0.05259, iou_score - 0.952, fscore - 0.9754]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.86it/s, dice_loss + focal_loss - 0.06355, iou_score - 0.9394, fscore - 0.9687]
#
# Epoch 0090  |  LR = 6.73e-05
# train: 100%|██████████| 10/10 [00:14<00:00,  1.48s/it, dice_loss + focal_loss - 0.05508, iou_score - 0.9512, fscore - 0.975]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.68it/s, dice_loss + focal_loss - 0.06439, iou_score - 0.9312, fscore - 0.9644]
#
# Epoch 0091  |  LR = 6.58e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.21it/s, dice_loss + focal_loss - 0.04993, iou_score - 0.9558, fscore - 0.9774]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.98it/s, dice_loss + focal_loss - 0.06251, iou_score - 0.9386, fscore - 0.9683]
#   ✅ Val loss ↓  → 0.0625  (epoch 0091)
#
# Epoch 0092  |  LR = 6.43e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.18it/s, dice_loss + focal_loss - 0.0561, iou_score - 0.9492, fscore - 0.9739]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.98it/s, dice_loss + focal_loss - 0.0678, iou_score - 0.9238, fscore - 0.9603]
#
# Epoch 0093  |  LR = 6.28e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.14it/s, dice_loss + focal_loss - 0.05203, iou_score - 0.9534, fscore - 0.9761]
# valid: 100%|██████████| 2/2 [00:12<00:00,  6.43s/it, dice_loss + focal_loss - 0.06425, iou_score - 0.9355, fscore - 0.9667]
#
# Epoch 0094  |  LR = 6.13e-05
# train: 100%|██████████| 10/10 [00:14<00:00,  1.45s/it, dice_loss + focal_loss - 0.05192, iou_score - 0.9542, fscore - 0.9765]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.84it/s, dice_loss + focal_loss - 0.06511, iou_score - 0.9318, fscore - 0.9647]
#
# Epoch 0095  |  LR = 5.98e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.53it/s, dice_loss + focal_loss - 0.05068, iou_score - 0.9544, fscore - 0.9766]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.21it/s, dice_loss + focal_loss - 0.06288, iou_score - 0.9374, fscore - 0.9677]
#
# Epoch 0096  |  LR = 5.82e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.94it/s, dice_loss + focal_loss - 0.04895, iou_score - 0.9568, fscore - 0.9779]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.71it/s, dice_loss + focal_loss - 0.05931, iou_score - 0.9406, fscore - 0.9694]
#   ✅ Val loss ↓  → 0.0593  (epoch 0096)
#
# Epoch 0097  |  LR = 5.67e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.72it/s, dice_loss + focal_loss - 0.04999, iou_score - 0.9512, fscore - 0.975]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.89it/s, dice_loss + focal_loss - 0.06088, iou_score - 0.938, fscore - 0.968]
#
# Epoch 0098  |  LR = 5.52e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.63it/s, dice_loss + focal_loss - 0.04803, iou_score - 0.9563, fscore - 0.9776]
# valid: 100%|██████████| 2/2 [00:11<00:00,  5.87s/it, dice_loss + focal_loss - 0.06141, iou_score - 0.9379, fscore - 0.968]
#
# Epoch 0099  |  LR = 5.36e-05
# train: 100%|██████████| 10/10 [00:14<00:00,  1.44s/it, dice_loss + focal_loss - 0.05077, iou_score - 0.9523, fscore - 0.9755]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.80it/s, dice_loss + focal_loss - 0.05957, iou_score - 0.9359, fscore - 0.9669]
#
# Epoch 0100  |  LR = 5.21e-05
# train: 100%|██████████| 10/10 [00:04<00:00,  2.47it/s, dice_loss + focal_loss - 0.04943, iou_score - 0.9541, fscore - 0.9765]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.13it/s, dice_loss + focal_loss - 0.05821, iou_score - 0.9413, fscore - 0.9698]
#   ✅ Val loss ↓  → 0.0582  (epoch 0100)
#   ✅ Val IoU  ↑  → 0.9413  (epoch 0100)
#
# Epoch 0101  |  LR = 5.05e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.12it/s, dice_loss + focal_loss - 0.04763, iou_score - 0.956, fscore - 0.9775]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.88it/s, dice_loss + focal_loss - 0.0585, iou_score - 0.9391, fscore - 0.9686]
#
# Epoch 0102  |  LR = 4.89e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.06it/s, dice_loss + focal_loss - 0.04828, iou_score - 0.9546, fscore - 0.9767]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.70it/s, dice_loss + focal_loss - 0.05938, iou_score - 0.9365, fscore - 0.9672]
#
# Epoch 0103  |  LR = 4.74e-05
# train: 100%|██████████| 10/10 [00:26<00:00,  2.64s/it, dice_loss + focal_loss - 0.04788, iou_score - 0.9553, fscore - 0.977]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.11it/s, dice_loss + focal_loss - 0.05834, iou_score - 0.94, fscore - 0.9691]
#
# Epoch 0104  |  LR = 4.58e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.56it/s, dice_loss + focal_loss - 0.04703, iou_score - 0.9563, fscore - 0.9777]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.16it/s, dice_loss + focal_loss - 0.05914, iou_score - 0.9351, fscore - 0.9665]
#
# Epoch 0105  |  LR = 4.43e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.10it/s, dice_loss + focal_loss - 0.04797, iou_score - 0.9538, fscore - 0.9763]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.17it/s, dice_loss + focal_loss - 0.05943, iou_score - 0.9366, fscore - 0.9673]
#
# Epoch 0106  |  LR = 4.28e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.13it/s, dice_loss + focal_loss - 0.04722, iou_score - 0.9561, fscore - 0.9775]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.70it/s, dice_loss + focal_loss - 0.05854, iou_score - 0.9381, fscore - 0.968]
#
# Epoch 0107  |  LR = 4.12e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.97it/s, dice_loss + focal_loss - 0.04314, iou_score - 0.9605, fscore - 0.9798]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.91it/s, dice_loss + focal_loss - 0.05755, iou_score - 0.9378, fscore - 0.9679]
#   ✅ Val loss ↓  → 0.0576  (epoch 0107)
#
# Epoch 0108  |  LR = 3.97e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.85it/s, dice_loss + focal_loss - 0.04572, iou_score - 0.9579, fscore - 0.9785]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.90it/s, dice_loss + focal_loss - 0.05822, iou_score - 0.9388, fscore - 0.9684]
#
# Epoch 0109  |  LR = 3.82e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.16it/s, dice_loss + focal_loss - 0.04607, iou_score - 0.9577, fscore - 0.9784]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.99it/s, dice_loss + focal_loss - 0.05828, iou_score - 0.9371, fscore - 0.9675]
#
# Epoch 0110  |  LR = 3.67e-05
# train: 100%|██████████| 10/10 [00:26<00:00,  2.69s/it, dice_loss + focal_loss - 0.04565, iou_score - 0.9557, fscore - 0.9773]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.08it/s, dice_loss + focal_loss - 0.05701, iou_score - 0.9378, fscore - 0.9679]
#   ✅ Val loss ↓  → 0.0570  (epoch 0110)
#
# Epoch 0111  |  LR = 3.52e-05
# train: 100%|██████████| 10/10 [00:04<00:00,  2.29it/s, dice_loss + focal_loss - 0.0405, iou_score - 0.9627, fscore - 0.981]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.68it/s, dice_loss + focal_loss - 0.05757, iou_score - 0.9393, fscore - 0.9687]
#
# Epoch 0112  |  LR = 3.37e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.16it/s, dice_loss + focal_loss - 0.04361, iou_score - 0.9603, fscore - 0.9797]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.01it/s, dice_loss + focal_loss - 0.05768, iou_score - 0.9359, fscore - 0.9669]
#
# Epoch 0113  |  LR = 3.23e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.12it/s, dice_loss + focal_loss - 0.04077, iou_score - 0.9611, fscore - 0.9801]
# valid: 100%|██████████| 2/2 [00:12<00:00,  6.34s/it, dice_loss + focal_loss - 0.05724, iou_score - 0.9372, fscore - 0.9676]
#
# Epoch 0114  |  LR = 3.08e-05
# train: 100%|██████████| 10/10 [00:14<00:00,  1.47s/it, dice_loss + focal_loss - 0.0441, iou_score - 0.9595, fscore - 0.9793]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.99it/s, dice_loss + focal_loss - 0.05707, iou_score - 0.9388, fscore - 0.9684]
#
# Epoch 0115  |  LR = 2.94e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.07it/s, dice_loss + focal_loss - 0.0434, iou_score - 0.9577, fscore - 0.9783]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.97it/s, dice_loss + focal_loss - 0.05665, iou_score - 0.9363, fscore - 0.9671]
#   ✅ Val loss ↓  → 0.0567  (epoch 0115)
#
# Epoch 0116  |  LR = 2.80e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.81it/s, dice_loss + focal_loss - 0.04314, iou_score - 0.9595, fscore - 0.9793]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.98it/s, dice_loss + focal_loss - 0.0567, iou_score - 0.9387, fscore - 0.9684]
#
# Epoch 0117  |  LR = 2.67e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.97it/s, dice_loss + focal_loss - 0.03961, iou_score - 0.9637, fscore - 0.9815]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.20it/s, dice_loss + focal_loss - 0.0557, iou_score - 0.9394, fscore - 0.9687]
#   ✅ Val loss ↓  → 0.0557  (epoch 0117)
#
# Epoch 0118  |  LR = 2.53e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.06it/s, dice_loss + focal_loss - 0.04317, iou_score - 0.9588, fscore - 0.9788]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.01it/s, dice_loss + focal_loss - 0.05471, iou_score - 0.9403, fscore - 0.9692]
#   ✅ Val loss ↓  → 0.0547  (epoch 0118)
#
# Epoch 0119  |  LR = 2.40e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.81it/s, dice_loss + focal_loss - 0.0404, iou_score - 0.9625, fscore - 0.9809]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.95it/s, dice_loss + focal_loss - 0.05347, iou_score - 0.942, fscore - 0.9701]
#   ✅ Val loss ↓  → 0.0535  (epoch 0119)
#   ✅ Val IoU  ↑  → 0.9420  (epoch 0119)
#
# Epoch 0120  |  LR = 2.27e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.97it/s, dice_loss + focal_loss - 0.03975, iou_score - 0.9636, fscore - 0.9814]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.01it/s, dice_loss + focal_loss - 0.0545, iou_score - 0.9417, fscore - 0.97]
#
# Epoch 0121  |  LR = 2.14e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.23it/s, dice_loss + focal_loss - 0.04159, iou_score - 0.96, fscore - 0.9795]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.86it/s, dice_loss + focal_loss - 0.05545, iou_score - 0.9382, fscore - 0.9681]
#
# Epoch 0122  |  LR = 2.02e-05
# train: 100%|██████████| 10/10 [00:15<00:00,  1.54s/it, dice_loss + focal_loss - 0.0402, iou_score - 0.9617, fscore - 0.9805]
# valid: 100%|██████████| 2/2 [00:12<00:00,  6.02s/it, dice_loss + focal_loss - 0.05491, iou_score - 0.9397, fscore - 0.9689]
#
# Epoch 0123  |  LR = 1.89e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.20it/s, dice_loss + focal_loss - 0.04284, iou_score - 0.9592, fscore - 0.9791]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.96it/s, dice_loss + focal_loss - 0.05504, iou_score - 0.9395, fscore - 0.9688]
#
# Epoch 0124  |  LR = 1.78e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.73it/s, dice_loss + focal_loss - 0.04008, iou_score - 0.962, fscore - 0.9806]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.81it/s, dice_loss + focal_loss - 0.05597, iou_score - 0.9385, fscore - 0.9683]
#
# Epoch 0125  |  LR = 1.66e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.13it/s, dice_loss + focal_loss - 0.03978, iou_score - 0.9631, fscore - 0.9811]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.59it/s, dice_loss + focal_loss - 0.0563, iou_score - 0.9383, fscore - 0.9681]
#
# Epoch 0126  |  LR = 1.55e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.05it/s, dice_loss + focal_loss - 0.04215, iou_score - 0.9589, fscore - 0.979]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.01it/s, dice_loss + focal_loss - 0.05611, iou_score - 0.9366, fscore - 0.9673]
#
# Epoch 0127  |  LR = 1.44e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.66it/s, dice_loss + focal_loss - 0.04095, iou_score - 0.9594, fscore - 0.9792]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.39it/s, dice_loss + focal_loss - 0.05485, iou_score - 0.9388, fscore - 0.9685]
#
# Epoch 0128  |  LR = 1.34e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.63it/s, dice_loss + focal_loss - 0.04071, iou_score - 0.9622, fscore - 0.9807]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.64it/s, dice_loss + focal_loss - 0.05469, iou_score - 0.9386, fscore - 0.9683]
#
# Epoch 0129  |  LR = 1.24e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.01it/s, dice_loss + focal_loss - 0.04081, iou_score - 0.9609, fscore - 0.98]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.69it/s, dice_loss + focal_loss - 0.054, iou_score - 0.9413, fscore - 0.9697]
#
# Epoch 0130  |  LR = 1.14e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.94it/s, dice_loss + focal_loss - 0.0405, iou_score - 0.9618, fscore - 0.9805]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.03it/s, dice_loss + focal_loss - 0.05399, iou_score - 0.9412, fscore - 0.9697]
#
# Epoch 0131  |  LR = 1.05e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.54it/s, dice_loss + focal_loss - 0.03669, iou_score - 0.9665, fscore - 0.9829]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.90it/s, dice_loss + focal_loss - 0.05448, iou_score - 0.9409, fscore - 0.9695]
#
# Epoch 0132  |  LR = 9.56e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  3.12it/s, dice_loss + focal_loss - 0.04238, iou_score - 0.9595, fscore - 0.9793]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.83it/s, dice_loss + focal_loss - 0.05414, iou_score - 0.9414, fscore - 0.9698]
#
# Epoch 0133  |  LR = 8.71e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  3.19it/s, dice_loss + focal_loss - 0.04038, iou_score - 0.9612, fscore - 0.9802]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.85it/s, dice_loss + focal_loss - 0.05399, iou_score - 0.941, fscore - 0.9696]
#
# Epoch 0134  |  LR = 7.89e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  3.07it/s, dice_loss + focal_loss - 0.04098, iou_score - 0.9607, fscore - 0.9799]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.94it/s, dice_loss + focal_loss - 0.05408, iou_score - 0.9405, fscore - 0.9693]
#
# Epoch 0135  |  LR = 7.12e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  2.78it/s, dice_loss + focal_loss - 0.03858, iou_score - 0.9637, fscore - 0.9815]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.96it/s, dice_loss + focal_loss - 0.05388, iou_score - 0.9411, fscore - 0.9696]
#
# Epoch 0136  |  LR = 6.40e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  3.22it/s, dice_loss + focal_loss - 0.04038, iou_score - 0.9613, fscore - 0.9802]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.95it/s, dice_loss + focal_loss - 0.05373, iou_score - 0.9415, fscore - 0.9698]
#
# Epoch 0137  |  LR = 5.71e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  3.30it/s, dice_loss + focal_loss - 0.04195, iou_score - 0.9599, fscore - 0.9795]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.65it/s, dice_loss + focal_loss - 0.05354, iou_score - 0.9416, fscore - 0.9699]
#
# Epoch 0138  |  LR = 5.07e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  2.81it/s, dice_loss + focal_loss - 0.03748, iou_score - 0.9654, fscore - 0.9824]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.06it/s, dice_loss + focal_loss - 0.0538, iou_score - 0.9409, fscore - 0.9695]
#
# Epoch 0139  |  LR = 4.48e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  2.95it/s, dice_loss + focal_loss - 0.03772, iou_score - 0.9647, fscore - 0.982]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.96it/s, dice_loss + focal_loss - 0.0535, iou_score - 0.9417, fscore - 0.97]
#
# Epoch 0140  |  LR = 3.93e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  3.22it/s, dice_loss + focal_loss - 0.03977, iou_score - 0.962, fscore - 0.9806]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s, dice_loss + focal_loss - 0.05396, iou_score - 0.9412, fscore - 0.9697]
#
# Epoch 0141  |  LR = 3.42e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  3.30it/s, dice_loss + focal_loss - 0.03647, iou_score - 0.9663, fscore - 0.9828]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.10it/s, dice_loss + focal_loss - 0.05381, iou_score - 0.9409, fscore - 0.9695]
#
# Epoch 0142  |  LR = 2.97e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  2.87it/s, dice_loss + focal_loss - 0.0362, iou_score - 0.9663, fscore - 0.9828]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.98it/s, dice_loss + focal_loss - 0.0541, iou_score - 0.9403, fscore - 0.9692]
#
# Epoch 0143  |  LR = 2.56e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  3.02it/s, dice_loss + focal_loss - 0.03815, iou_score - 0.9642, fscore - 0.9817]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.02it/s, dice_loss + focal_loss - 0.05387, iou_score - 0.9408, fscore - 0.9695]
#
# Epoch 0144  |  LR = 2.19e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  3.22it/s, dice_loss + focal_loss - 0.04113, iou_score - 0.9612, fscore - 0.9801]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.89it/s, dice_loss + focal_loss - 0.0541, iou_score - 0.941, fscore - 0.9696]
#
# Epoch 0145  |  LR = 1.88e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  3.20it/s, dice_loss + focal_loss - 0.0397, iou_score - 0.9622, fscore - 0.9807]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.68it/s, dice_loss + focal_loss - 0.05419, iou_score - 0.9405, fscore - 0.9693]
#
# Epoch 0146  |  LR = 1.61e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  2.66it/s, dice_loss + focal_loss - 0.03664, iou_score - 0.9665, fscore - 0.983]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.92it/s, dice_loss + focal_loss - 0.05464, iou_score - 0.9403, fscore - 0.9692]
#
# Epoch 0147  |  LR = 1.39e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  3.19it/s, dice_loss + focal_loss - 0.0377, iou_score - 0.9658, fscore - 0.9826]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.98it/s, dice_loss + focal_loss - 0.05404, iou_score - 0.9413, fscore - 0.9698]
#
# Epoch 0148  |  LR = 1.22e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  3.17it/s, dice_loss + focal_loss - 0.03862, iou_score - 0.9631, fscore - 0.9812]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.90it/s, dice_loss + focal_loss - 0.0539, iou_score - 0.9415, fscore - 0.9699]
#
# Epoch 0149  |  LR = 1.10e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  3.17it/s, dice_loss + focal_loss - 0.03774, iou_score - 0.9646, fscore - 0.9819]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.16it/s, dice_loss + focal_loss - 0.05343, iou_score - 0.9413, fscore - 0.9697]
#   ✅ Val loss ↓  → 0.0534  (epoch 0149)
#
# Epoch 0150  |  LR = 1.02e-06
# train: 100%|██████████| 10/10 [00:03<00:00,  2.87it/s, dice_loss + focal_loss - 0.04076, iou_score - 0.9614, fscore - 0.9803]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.97it/s, dice_loss + focal_loss - 0.0529, iou_score - 0.9419, fscore - 0.9701]
#   ✅ Val loss ↓  → 0.0529  (epoch 0150)
#
# Epoch 0151  |  LR = 1.00e-04
# train: 100%|██████████| 10/10 [00:03<00:00,  3.11it/s, dice_loss + focal_loss - 0.04077, iou_score - 0.9592, fscore - 0.9791]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.74it/s, dice_loss + focal_loss - 0.05664, iou_score - 0.94, fscore - 0.9691]
#
# Epoch 0152  |  LR = 1.00e-04
# train: 100%|██████████| 10/10 [00:03<00:00,  2.54it/s, dice_loss + focal_loss - 0.04069, iou_score - 0.9602, fscore - 0.9797]
# valid: 100%|██████████| 2/2 [00:10<00:00,  5.30s/it, dice_loss + focal_loss - 0.056, iou_score - 0.9361, fscore - 0.967]
#
# Epoch 0153  |  LR = 1.00e-04
# train: 100%|██████████| 10/10 [00:03<00:00,  2.70it/s, dice_loss + focal_loss - 0.04855, iou_score - 0.9499, fscore - 0.9742]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.09it/s, dice_loss + focal_loss - 0.07046, iou_score - 0.9031, fscore - 0.949]
#
# Epoch 0154  |  LR = 9.99e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.16it/s, dice_loss + focal_loss - 0.05138, iou_score - 0.9434, fscore - 0.9708]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.97it/s, dice_loss + focal_loss - 0.06038, iou_score - 0.9306, fscore - 0.964]
#
# Epoch 0155  |  LR = 9.99e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.10it/s, dice_loss + focal_loss - 0.05198, iou_score - 0.9411, fscore - 0.9696]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.50it/s, dice_loss + focal_loss - 0.05459, iou_score - 0.9403, fscore - 0.9692]
#
# Epoch 0156  |  LR = 9.98e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.07it/s, dice_loss + focal_loss - 0.04561, iou_score - 0.952, fscore - 0.9754]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.86it/s, dice_loss + focal_loss - 0.05134, iou_score - 0.9379, fscore - 0.9679]
#   ✅ Val loss ↓  → 0.0513  (epoch 0156)
#
# Epoch 0157  |  LR = 9.98e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.95it/s, dice_loss + focal_loss - 0.04826, iou_score - 0.9481, fscore - 0.9733]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.05it/s, dice_loss + focal_loss - 0.05338, iou_score - 0.9366, fscore - 0.9673]
#
# Epoch 0158  |  LR = 9.97e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.11it/s, dice_loss + focal_loss - 0.05163, iou_score - 0.9404, fscore - 0.9692]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.48it/s, dice_loss + focal_loss - 0.05447, iou_score - 0.9364, fscore - 0.9672]
#
# Epoch 0159  |  LR = 9.96e-05
# ...
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.98it/s, dice_loss + focal_loss - 0.05054, iou_score - 0.9312, fscore - 0.9644]
#
# Epoch 0202  |  LR = 8.49e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.91it/s, dice_loss + focal_loss - 0.03227, iou_score - 0.9618, fscore - 0.9805]
# valid: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s, dice_loss + focal_loss - 0.04763, iou_score - 0.9381, fscore - 0.9681]
#
# Epoch 0203  |  LR = 8.44e-05
# train: 100%|██████████| 10/10 [00:04<00:00,  2.07it/s, dice_loss + focal_loss - 0.03171, iou_score - 0.9614, fscore - 0.9803]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.93it/s, dice_loss + focal_loss - 0.04875, iou_score - 0.9346, fscore - 0.9662]
#
# Epoch 0204  |  LR = 8.38e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.26it/s, dice_loss + focal_loss - 0.03233, iou_score - 0.9607, fscore - 0.9799]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.01it/s, dice_loss + focal_loss - 0.04863, iou_score - 0.9366, fscore - 0.9672]
#
# Epoch 0205  |  LR = 8.32e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.30it/s, dice_loss + focal_loss - 0.03171, iou_score - 0.9631, fscore - 0.9812]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.48it/s, dice_loss + focal_loss - 0.04681, iou_score - 0.9383, fscore - 0.9682]
#   ✅ Val loss ↓  → 0.0468  (epoch 0205)
#
# Epoch 0206  |  LR = 8.26e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.84it/s, dice_loss + focal_loss - 0.03119, iou_score - 0.9614, fscore - 0.9803]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.95it/s, dice_loss + focal_loss - 0.04854, iou_score - 0.9401, fscore - 0.9691]
#
# Epoch 0207  |  LR = 8.21e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.24it/s, dice_loss + focal_loss - 0.03104, iou_score - 0.9623, fscore - 0.9807]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.89it/s, dice_loss + focal_loss - 0.04911, iou_score - 0.9361, fscore - 0.967]
#
# Epoch 0208  |  LR = 8.14e-05
# train: 100%|██████████| 10/10 [00:14<00:00,  1.45s/it, dice_loss + focal_loss - 0.02954, iou_score - 0.9652, fscore - 0.9823]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.12it/s, dice_loss + focal_loss - 0.0502, iou_score - 0.9344, fscore - 0.9661]
#
# Epoch 0209  |  LR = 8.08e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.17it/s, dice_loss + focal_loss - 0.03041, iou_score - 0.964, fscore - 0.9817]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.97it/s, dice_loss + focal_loss - 0.05108, iou_score - 0.9339, fscore - 0.9658]
#
# Epoch 0210  |  LR = 8.02e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.57it/s, dice_loss + focal_loss - 0.02713, iou_score - 0.9683, fscore - 0.9839]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.53it/s, dice_loss + focal_loss - 0.04937, iou_score - 0.9372, fscore - 0.9676]
#
# Epoch 0211  |  LR = 7.96e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.07it/s, dice_loss + focal_loss - 0.02891, iou_score - 0.9651, fscore - 0.9822]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.91it/s, dice_loss + focal_loss - 0.04926, iou_score - 0.9348, fscore - 0.9663]
#
# Epoch 0212  |  LR = 7.90e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.06it/s, dice_loss + focal_loss - 0.02987, iou_score - 0.9639, fscore - 0.9816]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.82it/s, dice_loss + focal_loss - 0.05045, iou_score - 0.9378, fscore - 0.9679]
#
# Epoch 0213  |  LR = 7.83e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.63it/s, dice_loss + focal_loss - 0.03103, iou_score - 0.9637, fscore - 0.9815]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.65it/s, dice_loss + focal_loss - 0.05147, iou_score - 0.9333, fscore - 0.9655]
#
# Epoch 0214  |  LR = 7.77e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.73it/s, dice_loss + focal_loss - 0.02571, iou_score - 0.9696, fscore - 0.9845]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.81it/s, dice_loss + focal_loss - 0.05128, iou_score - 0.9393, fscore - 0.9687]
#
# Epoch 0215  |  LR = 7.70e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.99it/s, dice_loss + focal_loss - 0.02576, iou_score - 0.9697, fscore - 0.9846]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.82it/s, dice_loss + focal_loss - 0.04994, iou_score - 0.9355, fscore - 0.9667]
#
# Epoch 0216  |  LR = 7.64e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.03it/s, dice_loss + focal_loss - 0.02735, iou_score - 0.9672, fscore - 0.9833]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.97it/s, dice_loss + focal_loss - 0.04767, iou_score - 0.9414, fscore - 0.9698]
#
# Epoch 0217  |  LR = 7.57e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.61it/s, dice_loss + focal_loss - 0.02763, iou_score - 0.9667, fscore - 0.983]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.92it/s, dice_loss + focal_loss - 0.04514, iou_score - 0.9403, fscore - 0.9692]
#   ✅ Val loss ↓  → 0.0451  (epoch 0217)
#
# Epoch 0218  |  LR = 7.50e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.98it/s, dice_loss + focal_loss - 0.0268, iou_score - 0.9679, fscore - 0.9837]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.05it/s, dice_loss + focal_loss - 0.04583, iou_score - 0.9433, fscore - 0.9708]
#
# Epoch 0219  |  LR = 7.43e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.19it/s, dice_loss + focal_loss - 0.02776, iou_score - 0.9669, fscore - 0.9831]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.33it/s, dice_loss + focal_loss - 0.04788, iou_score - 0.9372, fscore - 0.9676]
#
# Epoch 0220  |  LR = 7.37e-05
# train: 100%|██████████| 10/10 [00:13<00:00,  1.39s/it, dice_loss + focal_loss - 0.02443, iou_score - 0.9704, fscore - 0.9849]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.01it/s, dice_loss + focal_loss - 0.04813, iou_score - 0.9394, fscore - 0.9687]
#
# Epoch 0221  |  LR = 7.30e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.73it/s, dice_loss + focal_loss - 0.02688, iou_score - 0.9696, fscore - 0.9845]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.14it/s, dice_loss + focal_loss - 0.04817, iou_score - 0.9357, fscore - 0.9668]
#
# Epoch 0222  |  LR = 7.23e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.24it/s, dice_loss + focal_loss - 0.02674, iou_score - 0.9666, fscore - 0.983]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.65it/s, dice_loss + focal_loss - 0.04855, iou_score - 0.9402, fscore - 0.9692]
#
# Epoch 0223  |  LR = 7.16e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.14it/s, dice_loss + focal_loss - 0.02687, iou_score - 0.9685, fscore - 0.984]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.88it/s, dice_loss + focal_loss - 0.04989, iou_score - 0.9347, fscore - 0.9662]
#
# Epoch 0224  |  LR = 7.09e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.94it/s, dice_loss + focal_loss - 0.02536, iou_score - 0.9689, fscore - 0.9842]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.79it/s, dice_loss + focal_loss - 0.04927, iou_score - 0.9383, fscore - 0.9682]
#
# Epoch 0225  |  LR = 7.02e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.65it/s, dice_loss + focal_loss - 0.02423, iou_score - 0.9716, fscore - 0.9856]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.79it/s, dice_loss + focal_loss - 0.04833, iou_score - 0.9364, fscore - 0.9672]
#
# Epoch 0226  |  LR = 6.94e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.04it/s, dice_loss + focal_loss - 0.02412, iou_score - 0.9716, fscore - 0.9856]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.77it/s, dice_loss + focal_loss - 0.04824, iou_score - 0.9406, fscore - 0.9694]
#
# Epoch 0227  |  LR = 6.87e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.08it/s, dice_loss + focal_loss - 0.02476, iou_score - 0.9696, fscore - 0.9846]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.74it/s, dice_loss + focal_loss - 0.04925, iou_score - 0.9366, fscore - 0.9673]
#
# Epoch 0228  |  LR = 6.80e-05
# train: 100%|██████████| 10/10 [00:04<00:00,  2.49it/s, dice_loss + focal_loss - 0.02659, iou_score - 0.9676, fscore - 0.9835]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.99it/s, dice_loss + focal_loss - 0.04948, iou_score - 0.9365, fscore - 0.9672]
#
# Epoch 0229  |  LR = 6.73e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.99it/s, dice_loss + focal_loss - 0.02563, iou_score - 0.9687, fscore - 0.9841]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.90it/s, dice_loss + focal_loss - 0.04932, iou_score - 0.9369, fscore - 0.9674]
#
# Epoch 0230  |  LR = 6.65e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.08it/s, dice_loss + focal_loss - 0.0249, iou_score - 0.971, fscore - 0.9853]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.75it/s, dice_loss + focal_loss - 0.04785, iou_score - 0.9378, fscore - 0.9679]
#
# Epoch 0231  |  LR = 6.58e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.10it/s, dice_loss + focal_loss - 0.02428, iou_score - 0.9701, fscore - 0.9848]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.99it/s, dice_loss + focal_loss - 0.04879, iou_score - 0.9403, fscore - 0.9692]
#
# Epoch 0232  |  LR = 6.51e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.60it/s, dice_loss + focal_loss - 0.02498, iou_score - 0.9704, fscore - 0.9849]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.80it/s, dice_loss + focal_loss - 0.04877, iou_score - 0.9377, fscore - 0.9679]
#
# Epoch 0233  |  LR = 6.43e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.18it/s, dice_loss + focal_loss - 0.02625, iou_score - 0.969, fscore - 0.9842]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.99it/s, dice_loss + focal_loss - 0.04974, iou_score - 0.9373, fscore - 0.9676]
#
# Epoch 0234  |  LR = 6.36e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.16it/s, dice_loss + focal_loss - 0.02453, iou_score - 0.9703, fscore - 0.9849]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.96it/s, dice_loss + focal_loss - 0.04925, iou_score - 0.9388, fscore - 0.9684]
#
# Epoch 0235  |  LR = 6.28e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.11it/s, dice_loss + focal_loss - 0.02411, iou_score - 0.9704, fscore - 0.9849]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.00it/s, dice_loss + focal_loss - 0.0479, iou_score - 0.9402, fscore - 0.9692]
#
# Epoch 0236  |  LR = 6.21e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.69it/s, dice_loss + focal_loss - 0.02337, iou_score - 0.9723, fscore - 0.9859]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.79it/s, dice_loss + focal_loss - 0.04724, iou_score - 0.9414, fscore - 0.9698]
#
# Epoch 0237  |  LR = 6.13e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.21it/s, dice_loss + focal_loss - 0.02282, iou_score - 0.9725, fscore - 0.9861]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.93it/s, dice_loss + focal_loss - 0.04873, iou_score - 0.9376, fscore - 0.9678]
#
# Epoch 0238  |  LR = 6.05e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.22it/s, dice_loss + focal_loss - 0.02235, iou_score - 0.9729, fscore - 0.9863]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.59it/s, dice_loss + focal_loss - 0.04898, iou_score - 0.9381, fscore - 0.968]
#
# Epoch 0239  |  LR = 5.98e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.79it/s, dice_loss + focal_loss - 0.02283, iou_score - 0.9725, fscore - 0.986]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.12it/s, dice_loss + focal_loss - 0.04784, iou_score - 0.9395, fscore - 0.9688]
#
# Epoch 0240  |  LR = 5.90e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.91it/s, dice_loss + focal_loss - 0.02194, iou_score - 0.9729, fscore - 0.9863]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.26it/s, dice_loss + focal_loss - 0.04763, iou_score - 0.9395, fscore - 0.9688]
#
# Epoch 0241  |  LR = 5.82e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.24it/s, dice_loss + focal_loss - 0.02393, iou_score - 0.9717, fscore - 0.9856]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.91it/s, dice_loss + focal_loss - 0.04705, iou_score - 0.9395, fscore - 0.9688]
#
# Epoch 0242  |  LR = 5.75e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.21it/s, dice_loss + focal_loss - 0.02279, iou_score - 0.972, fscore - 0.9858]
# valid: 100%|██████████| 2/2 [00:00<00:00,  4.15it/s, dice_loss + focal_loss - 0.04728, iou_score - 0.9402, fscore - 0.9692]
#
# Epoch 0243  |  LR = 5.67e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.95it/s, dice_loss + focal_loss - 0.02477, iou_score - 0.9701, fscore - 0.9848]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.82it/s, dice_loss + focal_loss - 0.04796, iou_score - 0.9402, fscore - 0.9692]
#
# Epoch 0244  |  LR = 5.59e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.92it/s, dice_loss + focal_loss - 0.02341, iou_score - 0.9713, fscore - 0.9854]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.91it/s, dice_loss + focal_loss - 0.04689, iou_score - 0.9419, fscore - 0.9701]
#
# Epoch 0245  |  LR = 5.52e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.19it/s, dice_loss + focal_loss - 0.02427, iou_score - 0.9711, fscore - 0.9853]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.98it/s, dice_loss + focal_loss - 0.04626, iou_score - 0.9414, fscore - 0.9698]
#
# Epoch 0246  |  LR = 5.44e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.18it/s, dice_loss + focal_loss - 0.02193, iou_score - 0.9727, fscore - 0.9862]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.76it/s, dice_loss + focal_loss - 0.04777, iou_score - 0.9399, fscore - 0.969]
#
# Epoch 0247  |  LR = 5.36e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.62it/s, dice_loss + focal_loss - 0.02258, iou_score - 0.9732, fscore - 0.9864]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.86it/s, dice_loss + focal_loss - 0.0484, iou_score - 0.9378, fscore - 0.9679]
#
# Epoch 0248  |  LR = 5.28e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.12it/s, dice_loss + focal_loss - 0.02413, iou_score - 0.9692, fscore - 0.9843]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.97it/s, dice_loss + focal_loss - 0.04702, iou_score - 0.9414, fscore - 0.9698]
#
# Epoch 0249  |  LR = 5.21e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.15it/s, dice_loss + focal_loss - 0.02132, iou_score - 0.9744, fscore - 0.987]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.96it/s, dice_loss + focal_loss - 0.04704, iou_score - 0.9386, fscore - 0.9683]
#
# Epoch 0250  |  LR = 5.13e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.08it/s, dice_loss + focal_loss - 0.02161, iou_score - 0.9743, fscore - 0.9869]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.00it/s, dice_loss + focal_loss - 0.04759, iou_score - 0.9394, fscore - 0.9688]
#
# Epoch 0251  |  LR = 5.05e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.70it/s, dice_loss + focal_loss - 0.02167, iou_score - 0.9736, fscore - 0.9866]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.95it/s, dice_loss + focal_loss - 0.04807, iou_score - 0.9379, fscore - 0.968]
#
# Epoch 0252  |  LR = 4.97e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.14it/s, dice_loss + focal_loss - 0.02177, iou_score - 0.9747, fscore - 0.9872]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.99it/s, dice_loss + focal_loss - 0.04781, iou_score - 0.9399, fscore - 0.969]
#
# Epoch 0253  |  LR = 4.89e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.15it/s, dice_loss + focal_loss - 0.02102, iou_score - 0.9738, fscore - 0.9867]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.92it/s, dice_loss + focal_loss - 0.04743, iou_score - 0.9401, fscore - 0.9691]
#
# Epoch 0254  |  LR = 4.82e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.12it/s, dice_loss + focal_loss - 0.02163, iou_score - 0.9747, fscore - 0.9872]
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.88it/s, dice_loss + focal_loss - 0.04699, iou_score - 0.9427, fscore - 0.9705]
#
# Epoch 0255  |  LR = 4.74e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  2.72it/s, dice_loss + focal_loss - 0.02195, iou_score - 0.9735, fscore - 0.9866]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.81it/s, dice_loss + focal_loss - 0.04791, iou_score - 0.9402, fscore - 0.9692]
#
# Epoch 0256  |  LR = 4.66e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.17it/s, dice_loss + focal_loss - 0.02042, iou_score - 0.9754, fscore - 0.9875]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.86it/s, dice_loss + focal_loss - 0.04755, iou_score - 0.9415, fscore - 0.9698]
#
# Epoch 0257  |  LR = 4.58e-05
# train: 100%|██████████| 10/10 [00:03<00:00,  3.12it/s, dice_loss + focal_loss - 0.01957, iou_score - 0.9765, fscore - 0.9881]
# valid: 100%|██████████| 2/2 [00:00<00:00,  3.83it/s, dice_loss + focal_loss - 0.047, iou_score - 0.9416, fscore - 0.9699]
#
# ⛔ Early stopping at epoch 0257  (patience=40)
#
# 🏆 Best model epoch : 217

# %% [markdown]
# ## Plot loss & metric curves

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 8))

axes[0,0].plot(store_train_loss, 'r', label='train')
axes[0,0].plot(store_val_loss,   'b', label='val')
axes[0,0].set_title('Loss'); axes[0,0].legend(); axes[0,0].grid(True)

axes[0,1].plot(store_train_iou, 'r', label='train')
axes[0,1].plot(store_val_iou,   'b', label='val')
axes[0,1].set_title('IoU'); axes[0,1].legend(); axes[0,1].grid(True)

axes[1,0].plot(store_train_dice, 'r', label='train')
axes[1,0].plot(store_val_dice,   'b', label='val')
axes[1,0].set_title('Dice'); axes[1,0].legend(); axes[1,0].grid(True)

axes[1,1].plot(store_lr, 'g')
axes[1,1].set_title('Learning Rate'); axes[1,1].set_yscale('log'); axes[1,1].grid(True)

fig.suptitle(model_name, fontsize=10)
fig.tight_layout()

save_fig_dir = os.path.join(PROJECT_ROOT, 'plots')
os.makedirs(save_fig_dir, exist_ok=True)
fig.savefig(os.path.join(save_fig_dir, model_name + '.png'), dpi=150)
plt.show()

# %% [markdown]
# ## Inference & Evaluation

# %%
# ================================================================
#  COPY CELL NÀY VÀO NOTEBOOK CHÍNH, THAY THẾ CELL INFERENCE CŨ
# ================================================================

import torch
import os
import cv2
import numpy as np
import json
import warnings
from PIL import Image
warnings.filterwarnings('ignore')

# Load best model
checkpoint = torch.load(os.path.join(checkpoint_loc, 'best_model.pth'), map_location=DEVICE)
model.load_state_dict(checkpoint['state_dict'])
model.eval()
print(f'✅ Loaded best model từ epoch {checkpoint["epoch"]}')

# Test dataset
test_dataset = Dataset(
    list_IDs_test, x_test_dir, y_test_dir,
    augmentation   = get_validation_augmentation(),
    preprocessing  = get_preprocessing(preprocessing_fn),
    resize         = RESIZE,
    to_categorical = False,
    n_classes      = n_classes,
    # copypaste_bank = None,
)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False, num_workers=0)

# Save dirs
save_dir_pred         = os.path.join(PROJECT_ROOT, 'predictions',             model_name)
save_dir_pred_pal     = os.path.join(PROJECT_ROOT, 'predictions_palette',     model_name)
save_dir_pred_pal_cat = os.path.join(PROJECT_ROOT, 'predictions_palette_cat', model_name)
for d in [save_dir_pred, save_dir_pred_pal, save_dir_pred_pal_cat]:
    os.makedirs(d, exist_ok=True)

palette = [[0,0,0],[255,0,0],[0,255,0],[0,0,255]]
ep      = 1e-6

# ================================================================
#  Lưu metric theo 2 cách:
#  metric_raw  : giống cũ (kể cả FP-only)
#  metric_clean: chỉ tính khi GT có label đó
# ================================================================
metric_raw   = {}   # để save JSON (giữ nguyên như cũ)
metric_clean = {}   # để tính per-class summary đúng

# Dataset-level counters (giữ nguyên — vẫn đúng)
stp = sfp = sfn = 0

# Per-class counters CHỈ tính khi GT có label đó
# class_tp[c], class_fp[c], class_fn[c]
class_tp = {c: 0 for c in range(1, n_classes)}
class_fp = {c: 0 for c in range(1, n_classes)}
class_fn = {c: 0 for c in range(1, n_classes)}
class_n  = {c: 0 for c in range(1, n_classes)}  # số ảnh GT có label c

iter_loader = iter(test_loader)

for idx in range(len(list_IDs_test)):

    tp = fp = fn = 0
    name = os.path.splitext(list_IDs_test[idx])[0]
    metric_raw[name]   = {}
    metric_clean[name] = {}

    image, gt_mask = next(iter_loader)

    # Predict (TTA nếu bật)
    if USE_TTA:
        pr_prob = predict_with_tta(model, image, DEVICE)
    else:
        with torch.no_grad():
            pr_prob = model.predict(image.to(DEVICE))

    pr_mask = torch.argmax(pr_prob, dim=1)

    gt_mask = gt_mask.squeeze().cpu().numpy().astype(np.int64)
    pred    = pr_mask.squeeze().cpu().numpy()

    # Save ảnh
    cv2.imwrite(os.path.join(save_dir_pred, list_IDs_test[idx]),
                pred.astype(np.uint8))

    pal_gt = Image.fromarray(gt_mask.astype(np.uint8)).convert('P')
    pal_gt.putpalette(np.array(palette, dtype=np.uint8))

    pal_pr = Image.fromarray(pred.astype(np.uint8)).convert('P')
    pal_pr.putpalette(np.array(palette, dtype=np.uint8))
    pal_pr.save(os.path.join(save_dir_pred_pal, list_IDs_test[idx]))

    cat = Image.new('RGB', (pal_gt.width * 2, pal_gt.height), 'white')
    cat.paste(pal_gt, (0, 0))
    cat.paste(pal_pr, (pal_gt.width, 0))
    cat.save(os.path.join(save_dir_pred_pal_cat, list_IDs_test[idx]))

    # ==============================================================
    #  Tính metrics
    # ==============================================================
    lbl_gt   = set(np.unique(gt_mask)) - {0}
    lbl_pred = set(np.unique(pred))    - {0}

    # --- FP only: model predict nhầm, GT không có ---
    for d in (lbl_pred - lbl_gt):
        fp_pixels = len(np.argwhere(pred == d))
        fp += fp_pixels
        # ✅ KHÔNG đưa vào per-class summary vì GT không có label này
        # Nhưng vẫn tính vào dataset-level sfp
        metric_raw[name][str(d)] = [0, 0, 0, 0]
        print(f'{idx+1:3d} {name}: label {d} | ⚠️  FP only (GT không có label này)')

    # --- FN only: GT có nhưng model không predict ---
    for d in (lbl_gt - lbl_pred):
        fn_pixels = len(np.argwhere(gt_mask == d))
        fn += fn_pixels
        metric_raw[name][str(d)]   = [0, 0, 0, 0]
        metric_clean[name][str(d)] = [0, 0, 0, 0]

        # ✅ Tính vào per-class vì GT CÓ label này
        if d in class_fn:
            class_fn[d] += fn_pixels
            class_n[d]  += 1

        print(f'{idx+1:3d} {name}: label {d} | P:  0.00 R:  0.00 Dice:  0.00 IoU:  0.00  (GT có, model bỏ sót)')

    # --- Intersection: cả GT và predict đều có ---
    for c in (lbl_gt & lbl_pred):
        gt_set   = set(zip(*np.where(gt_mask == c)))
        pred_set = set(zip(*np.where(pred    == c)))

        tp_ = len(gt_set & pred_set)
        fp_ = len(pred_set - gt_set)
        fn_ = len(gt_set  - pred_set)

        tp += tp_; fp += fp_; fn += fn_

        p_    = tp_ / (tp_ + fp_ + ep) * 100
        r_    = tp_ / (tp_ + fn_ + ep) * 100
        dice_ = 2*tp_ / (2*tp_ + fp_ + fn_ + ep) * 100
        iou_  = tp_ / (tp_ + fp_ + fn_ + ep) * 100

        print(f'{idx+1:3d} {name}: label {c} | P:{p_:6.2f} R:{r_:6.2f} Dice:{dice_:6.2f} IoU:{iou_:6.2f}')

        metric_raw[name][str(c)]   = [p_, r_, dice_, iou_]
        metric_clean[name][str(c)] = [p_, r_, dice_, iou_]

        # ✅ Tính vào per-class vì GT CÓ label này
        if c in class_tp:
            class_tp[c] += tp_
            class_fp[c] += fp_
            class_fn[c] += fn_
            class_n[c]  += 1

    stp += tp; sfp += fp; sfn += fn

# Save JSON
with open(os.path.join(save_dir_pred, 'metric.json'), 'w') as f:
    json.dump(metric_raw, f, indent=2)

# ==============================================================
#  Dataset-level (giữ nguyên cách tính cũ — đúng)
# ==============================================================
siou  = stp / (stp + sfp + sfn + ep) * 100
sprec = stp / (stp + sfp + ep)       * 100
srec  = stp / (stp + sfn + ep)       * 100
sdice = 2*stp / (2*stp + sfp + sfn)  * 100

print('\n' + '='*45)
print('  Dataset-level Results')
print('='*45)
print(f'  IoU       : {siou:.4f}')
print(f'  Precision : {sprec:.4f}')
print(f'  Recall    : {srec:.4f}')
print(f'  Dice      : {sdice:.4f}')
print('='*45)

with open(os.path.join(save_dir_pred, 'result.txt'), 'w') as f:
    f.write(f'model_name  = {model_name}\n')
    f.write(f'encoder     = {ENCODER}\n')
    f.write(f'best_epoch  = {best_model_epoch}\n')
    f.write(f'iou         = {siou:.4f}\n')
    f.write(f'precision   = {sprec:.4f}\n')
    f.write(f'recall      = {srec:.4f}\n')
    f.write(f'dice        = {sdice:.4f}\n')

# ==============================================================
#  Per-class Summary — ĐÃ FIX
#  Chỉ tính ảnh mà ground truth THỰC SỰ có label đó
# ==============================================================

print(f"{'Label':>6} | {'Precision':>10} | {'Recall':>8} | {'Dice':>8} | {'IoU':>8} | {'N (GT có)':>10}")
print('-' * 66)

for c in range(1, n_classes):
    tp_ = class_tp[c]
    fp_ = class_fp[c]
    fn_ = class_fn[c]
    n_  = class_n[c]

    if n_ == 0:
        print(f"  {c:>4} | {'N/A':>10} | {'N/A':>8} | {'N/A':>8} | {'N/A':>8} | {n_:>10}")
        continue

    p_    = tp_ / (tp_ + fp_ + ep) * 100
    r_    = tp_ / (tp_ + fn_ + ep) * 100
    dice_ = 2*tp_ / (2*tp_ + fp_ + fn_ + ep) * 100
    iou_  = tp_ / (tp_ + fp_ + fn_ + ep) * 100

    print(f"  {c:>4} | {p_:>10.2f} | {r_:>8.2f} | {dice_:>8.2f} | {iou_:>8.2f} | {n_:>10}")

print('-' * 66)
print(f"\nOverall → IoU: {siou:.2f}  Dice: {sdice:.2f}  Prec: {sprec:.2f}  Rec: {srec:.2f}")
print()
print('Ghi chú: N (GT có) = số ảnh ground truth thực sự có label đó')
print('         Không tính ảnh model predict nhầm (FP only) vào N')

# So sánh với cách tính cũ
print('\n' + '='*55)
print('  So sánh cách tính cũ vs mới cho Label 1')
print('='*55)
print('  Cách cũ: tính cả ảnh FP-only vào N → IoU bị kéo xuống')
print('  Cách mới: chỉ tính ảnh GT có label 1 → IoU phản ánh đúng')
print('='*55)
print(f'\n📁 Kết quả lưu tại: {save_dir_pred}')
# Out:
# ✅ Loaded best model từ epoch 218
#   1 0914: label 1 | P: 82.79 R: 94.13 Dice: 88.10 IoU: 78.73
#   1 0914: label 3 | P: 78.31 R: 16.30 Dice: 26.98 IoU: 15.60
#   2 0925: label 1 | ⚠️  FP only (GT không có label này)
#   2 0925: label 2 | P: 98.73 R: 91.60 Dice: 95.03 IoU: 90.53
#   2 0925: label 3 | P: 91.97 R: 72.14 Dice: 80.86 IoU: 67.87
#   3 0927: label 1 | P: 61.64 R: 69.07 Dice: 65.14 IoU: 48.30
#   3 0927: label 2 | P: 85.99 R: 87.90 Dice: 86.93 IoU: 76.89
#   3 0927: label 3 | P: 35.46 R: 88.95 Dice: 50.71 IoU: 33.97
#   4 0935: label 1 | ⚠️  FP only (GT không có label này)
#   4 0935: label 2 | P: 91.35 R: 92.43 Dice: 91.89 IoU: 84.99
#   4 0935: label 3 | P: 57.93 R: 88.97 Dice: 70.17 IoU: 54.05
#   5 0961: label 1 | P: 86.75 R: 88.77 Dice: 87.75 IoU: 78.17
#   5 0961: label 2 | P: 80.94 R: 90.33 Dice: 85.38 IoU: 74.49
#   5 0961: label 3 | P: 53.47 R: 65.81 Dice: 59.00 IoU: 41.85
#   6 0962: label 1 | P: 10.88 R:100.00 Dice: 19.63 IoU: 10.88
#   6 0962: label 2 | P: 92.23 R: 31.56 Dice: 47.03 IoU: 30.74
#   6 0962: label 3 | P: 94.23 R: 87.58 Dice: 90.78 IoU: 83.12
#   7 0963: label 1 | ⚠️  FP only (GT không có label này)
#   7 0963: label 2 | P: 92.93 R: 54.34 Dice: 68.58 IoU: 52.18
#   7 0963: label 3 | P: 84.26 R: 93.99 Dice: 88.86 IoU: 79.95
#   8 0967: label 1 | ⚠️  FP only (GT không có label này)
#   8 0967: label 2 | P: 73.78 R: 61.10 Dice: 66.84 IoU: 50.20
#   8 0967: label 3 | P: 69.61 R: 82.86 Dice: 75.66 IoU: 60.85
#   9 0976: label 1 | P:  8.78 R:  7.26 Dice:  7.95 IoU:  4.14
#   9 0976: label 2 | P: 85.02 R: 94.56 Dice: 89.54 IoU: 81.06
#   9 0976: label 3 | P: 86.28 R: 84.19 Dice: 85.23 IoU: 74.25
#  10 0983: label 1 | ⚠️  FP only (GT không có label này)
#  10 0983: label 2 | P: 91.48 R: 68.61 Dice: 78.41 IoU: 64.49
#  10 0983: label 3 | P: 96.18 R: 79.29 Dice: 86.92 IoU: 76.86
#  11 0989: label 1 | P:100.00 R: 60.94 Dice: 75.73 IoU: 60.94
#  11 0989: label 3 | P: 73.81 R: 73.81 Dice: 73.81 IoU: 58.49
#  12 0994: label 1 | ⚠️  FP only (GT không có label này)
#  12 0994: label 2 | P: 88.24 R: 98.76 Dice: 93.21 IoU: 87.28
#  12 0994: label 3 | P: 74.55 R: 36.67 Dice: 49.16 IoU: 32.59
#  13 0996: label 1 | ⚠️  FP only (GT không có label này)
#  13 0996: label 2 | P: 93.08 R: 85.41 Dice: 89.08 IoU: 80.31
#  13 0996: label 3 | P: 90.90 R: 78.33 Dice: 84.15 IoU: 72.63
#  14 0999: label 1 | ⚠️  FP only (GT không có label này)
#  14 0999: label 2 | P: 93.23 R: 98.03 Dice: 95.57 IoU: 91.52
#  14 0999: label 3 | P: 88.59 R: 43.44 Dice: 58.29 IoU: 41.14
#  15 1004: label 1 | ⚠️  FP only (GT không có label này)
#  15 1004: label 2 | P: 85.80 R: 86.80 Dice: 86.30 IoU: 75.90
#  15 1004: label 3 | P: 95.05 R: 71.50 Dice: 81.61 IoU: 68.93
#  16 1005: label 2 | P: 96.78 R: 98.11 Dice: 97.44 IoU: 95.01
#  16 1005: label 3 | P: 96.41 R: 68.13 Dice: 79.84 IoU: 66.45
#
# =============================================
#   Dataset-level Results
# =============================================
#   IoU       : 68.7441
#   Precision : 82.4018
#   Recall    : 80.5734
#   Dice      : 81.4773
# =============================================
#  Label |  Precision |   Recall |     Dice |      IoU |  N (GT có)
# ------------------------------------------------------------------
#      1 |      67.61 |    77.64 |    72.28 |    56.59 |          6
#      2 |      89.89 |    92.28 |    91.07 |    83.61 |         14
#      3 |      79.41 |    70.26 |    74.55 |    59.43 |         16
# ------------------------------------------------------------------
#
# Overall → IoU: 68.74  Dice: 81.48  Prec: 82.40  Rec: 80.57
#
# Ghi chú: N (GT có) = số ảnh ground truth thực sự có label đó
#          Không tính ảnh model predict nhầm (FP only) vào N
#
# =======================================================
#   So sánh cách tính cũ vs mới cho Label 1
# =======================================================
#   Cách cũ: tính cả ảnh FP-only vào N → IoU bị kéo xuống
#   Cách mới: chỉ tính ảnh GT có label 1 → IoU phản ánh đúng
# =======================================================
#
# 📁 Kết quả lưu tại: /content/drive/MyDrive/DFUTissueSegNet/predictions/UNet_resnet50_improved_2026-05-06_01-59-39

# %% [markdown]
# ## Per-class summary
